# %% [markdown]
#  # Predicting World GDP Based On Countries Social,Economic And Cultural Data

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
#  ### Loading Data and Merging it

# %%
population_per_country = pd.read_csv('PopulationPerCountry.csv', skiprows = range(0,4))
population_per_country.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2009  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101453.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  28004331.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  22549547.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2927519.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     84462.0
#
#          2010        2011        2012        2013        2014        2015  \
# 0    101669.0    102053.0    102577.0    103187.0    103795.0    104341.0
# 1  28803167.0  29708599.0  30696958.0  31731688.0  32758020.0  33736494.0
# 2  23369131.0  24218565.0  25096150.0  25998340.0  26920466.0  27859305.0
# 3   2913021.0   2905195.0   2900401.0   2895092.0   2889104.0   2880703.0
# 4     84449.0     83751.0     82431.0     80788.0     79223.0     78014.0
#
#          2016  2017  Unnamed: 62
# 0    104822.0   NaN          NaN
# 1  34656032.0   NaN          NaN
# 2  28813463.0   NaN          NaN
# 3   2876101.0   NaN          NaN
# 4     77281.0   NaN          NaN
#
# [5 rows x 63 columns]

# %%
GDP_Country = pd.read_csv('GDP by Country.csv', skiprows = range(0,4))
GDP_Country.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#            2009          2010          2011          2012          2013  \
# 0  2.498933e+09  2.467704e+09  2.584464e+09           NaN           NaN
# 1  1.248694e+10  1.593680e+10  1.793024e+10  2.053654e+10  2.004633e+10
# 2  7.549238e+10  8.247091e+10  1.041159e+11  1.153984e+11  1.249121e+11
# 3  1.204421e+10  1.192695e+10  1.289087e+10  1.231978e+10  1.277628e+10
# 4  3.660531e+09  3.355695e+09  3.442063e+09  3.164615e+09  3.281585e+09
#
#            2014          2015          2016  2017  Unnamed: 62
# 0           NaN           NaN           NaN   NaN          NaN
# 1  2.005019e+10  1.921556e+10  1.946902e+10   NaN          NaN
# 2  1.267769e+11  1.029622e+11  9.533511e+10   NaN          NaN
# 3  1.322824e+10  1.133526e+10  1.186387e+10   NaN          NaN
# 4  3.350736e+09  2.811489e+09  2.858518e+09   NaN          NaN
#
# [5 rows x 63 columns]

# %%
GDP_Data = pd.merge(GDP_Country, population_per_country, on= ['Country Code','Country Name'], how='inner')
GDP_Data.head()
# Out:
#   Country Name Country Code   Indicator Name_x Indicator Code_x        1960_x  \
# 0        Aruba          ABW  GDP (current US$)   NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)   NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)   NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)   NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)   NY.GDP.MKTP.CD           NaN
#
#          1961_x        1962_x        1963_x        1964_x        1965_x  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#        2009_y      2010_y      2011_y      2012_y      2013_y      2014_y  \
# 0    101453.0    101669.0    102053.0    102577.0    103187.0    103795.0
# 1  28004331.0  28803167.0  29708599.0  30696958.0  31731688.0  32758020.0
# 2  22549547.0  23369131.0  24218565.0  25096150.0  25998340.0  26920466.0
# 3   2927519.0   2913021.0   2905195.0   2900401.0   2895092.0   2889104.0
# 4     84462.0     84449.0     83751.0     82431.0     80788.0     79223.0
#
#        2015_y      2016_y  2017_y  Unnamed: 62_y
# 0    104341.0    104822.0     NaN            NaN
# 1  33736494.0  34656032.0     NaN            NaN
# 2  27859305.0  28813463.0     NaN            NaN
# 3   2880703.0   2876101.0     NaN            NaN
# 4     78014.0     77281.0     NaN            NaN
#
# [5 rows x 124 columns]

# %%
GDP_Data = GDP_Data.drop(['Indicator Name_x','Indicator Code_x','Indicator Name_y','Indicator Code_y','Unnamed: 62_y','Unnamed: 62_x'], axis = 1)
GDP_Data.head()
# Out:
#   Country Name Country Code        1960_x        1961_x        1962_x  \
# 0        Aruba          ABW           NaN           NaN           NaN
# 1  Afghanistan          AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 2       Angola          AGO           NaN           NaN           NaN
# 3      Albania          ALB           NaN           NaN           NaN
# 4      Andorra          AND           NaN           NaN           NaN
#
#          1963_x        1964_x        1965_x        1966_x        1967_x  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#        2008_y      2009_y      2010_y      2011_y      2012_y      2013_y  \
# 0    101353.0    101453.0    101669.0    102053.0    102577.0    103187.0
# 1  27294031.0  28004331.0  28803167.0  29708599.0  30696958.0  31731688.0
# 2  21759420.0  22549547.0  23369131.0  24218565.0  25096150.0  25998340.0
# 3   2947314.0   2927519.0   2913021.0   2905195.0   2900401.0   2895092.0
# 4     83861.0     84462.0     84449.0     83751.0     82431.0     80788.0
#
#        2014_y      2015_y      2016_y  2017_y
# 0    103795.0    104341.0    104822.0     NaN
# 1  32758020.0  33736494.0  34656032.0     NaN
# 2  26920466.0  27859305.0  28813463.0     NaN
# 3   2889104.0   2880703.0   2876101.0     NaN
# 4     79223.0     78014.0     77281.0     NaN
#
# [5 rows x 118 columns]

# %%
GDP_Data1 = pd.DataFrame()
for col in GDP_Data.columns:
    if col.endswith("Name"):
        country = col[:]
        GDP_Data1[country] = GDP_Data[country]
    if col.endswith("_x"):
        year = col[:4]
        GDP_Data1[year] = GDP_Data[year + '_x']/GDP_Data[year + '_y']
    if col.endswith("Code"):
        code = col[:]
        GDP_Data1[code] = GDP_Data[code]
        
GDP_Data1.head()
# Out:
#   Country Name Country Code       1960       1961       1962       1963  \
# 0        Aruba          ABW        NaN        NaN        NaN        NaN
# 1  Afghanistan          AFG  59.777327  59.878153  58.492874  78.782758
# 2       Angola          AGO        NaN        NaN        NaN        NaN
# 3      Albania          ALB        NaN        NaN        NaN        NaN
# 4      Andorra          AND        NaN        NaN        NaN        NaN
#
#         1964        1965        1966     1967  ...          2008  \
# 0        NaN         NaN         NaN      NaN  ...  27546.899390
# 1  82.208444  101.290471  137.899362  161.322  ...    373.361116
# 2        NaN         NaN         NaN      NaN  ...   3868.578883
# 3        NaN         NaN         NaN      NaN  ...   4370.539647
# 4        NaN         NaN         NaN      NaN  ...  47785.659086
#
#            2009          2010          2011          2012          2013  \
# 0  24631.434860  24271.940421  25324.720362           NaN           NaN
# 1    445.893298    553.300289    603.537023    669.009051    631.744971
# 2   3347.844850   3529.053482   4299.012889   4598.249988   4804.616884
# 3   4114.136545   4094.358832   4437.178068   4247.614308   4413.081697
# 4  43339.379875  39736.354063  41098.766942  38391.080867  40619.711298
#
#            2014          2015          2016  2017
# 0           NaN           NaN           NaN   NaN
# 1    612.069651    569.577923    561.778746   NaN
# 2   4709.312024   3695.793748   3308.700233   NaN
# 3   4578.666728   3934.895394   4124.982390   NaN
# 4  42294.994727  36038.267604  36988.622030   NaN
#
# [5 rows x 60 columns]

# %%
GDP_Combine = pd.melt(GDP_Data1,id_vars=['Country Name','Country Code'])
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value
# 0        Aruba          ABW     1960        NaN
# 1  Afghanistan          AFG     1960  59.777327
# 2       Angola          AGO     1960        NaN
# 3      Albania          ALB     1960        NaN
# 4      Andorra          AND     1960        NaN

# %%
Women_Informed_Choices = pd.read_csv('WomenMakingInformedChoicestoReproductiveHealthCare.csv', skiprows = range(0,4))
Women_Informed_Choices.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS   NaN
# 1  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS   NaN
# 2  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS   NaN
# 3  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS   NaN
# 4  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2008  2009  2010  2011  2012  2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN  61.5   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2014  2015  2016  2017
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN
#
# [5 rows x 62 columns]

# %%
Women_Informed_Choices = pd.melt(Women_Informed_Choices,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
Women_Informed_Choices.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  \
# 0  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS
# 1  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS
# 2  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS
# 3  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS
# 4  Women making their own informed decisions rega...  SG.DMK.SRCR.FN.ZS
#
#   variable  value
# 0     1960    NaN
# 1     1960    NaN
# 2     1960    NaN
# 3     1960    NaN
# 4     1960    NaN

# %%
RuralPopulation_PerCent = pd.read_csv('RuralPopulationofTotalPopulation.csv', skiprows = range(0,4))
RuralPopulation_PerCent.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Rural population (% of total population)
# 1  Afghanistan          AFG  Rural population (% of total population)
# 2       Angola          AGO  Rural population (% of total population)
# 3      Albania          ALB  Rural population (% of total population)
# 4      Andorra          AND  Rural population (% of total population)
#
#    Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# 0  SP.RUR.TOTL.ZS  49.224  49.239  49.254  49.270  49.285  49.300  ...
# 1  SP.RUR.TOTL.ZS  91.779  91.492  91.195  90.890  90.574  90.250  ...
# 2  SP.RUR.TOTL.ZS  89.565  89.202  88.796  88.376  87.942  87.496  ...
# 3  SP.RUR.TOTL.ZS  69.295  69.057  68.985  68.914  68.842  68.770  ...
# 4  SP.RUR.TOTL.ZS  41.550  39.017  36.538  34.128  31.795  29.555  ...
#
#      2009    2010    2011    2012    2013    2014    2015    2016  2017  \
# 0  56.579  56.941  57.302  57.636  57.942  58.221  58.472  58.696   NaN
# 1  75.687  75.311  74.926  74.532  74.129  73.718  73.297  72.868   NaN
# 2  60.701  59.903  59.100  58.301  57.510  56.726  55.950  55.181   NaN
# 3  48.924  47.837  46.753  45.670  44.617  43.591  42.593  41.624   NaN
# 4  11.648  12.183  12.740  13.292  13.835  14.367  14.885  15.388   NaN
#
#    Unnamed: 62
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 63 columns]

# %%
RuralPopulation_PerCent = RuralPopulation_PerCent.drop(['Unnamed: 62'],axis = 1)
RuralPopulation_PerCent = pd.melt(RuralPopulation_PerCent,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
RuralPopulation_PerCent.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Rural population (% of total population)
# 1  Afghanistan          AFG  Rural population (% of total population)
# 2       Angola          AGO  Rural population (% of total population)
# 3      Albania          ALB  Rural population (% of total population)
# 4      Andorra          AND  Rural population (% of total population)
#
#    Indicator Code variable   value
# 0  SP.RUR.TOTL.ZS     1960  49.224
# 1  SP.RUR.TOTL.ZS     1960  91.779
# 2  SP.RUR.TOTL.ZS     1960  89.565
# 3  SP.RUR.TOTL.ZS     1960  69.295
# 4  SP.RUR.TOTL.ZS     1960  41.550

# %%
PublicEducation_Expenditure = pd.read_csv('public-education-expenditure-as-share-of-gdp.csv')
PublicEducation_Expenditure.head()
# Out:
#       Entity Code  Year  Public Expenditure on Education (percent of GDP)
# 0  Australia  AUS  1937                                               0.7
# 1  Australia  AUS  1960                                               1.4
# 2  Australia  AUS  1980                                               5.5
# 3  Australia  AUS  1993                                               6.0
# 4    Austria  AUT  1937                                               2.5

# %%
LegalRights_Strength = pd.read_csv('LegalRightsStrengthIndex.csv', skiprows = range(0,4))
LegalRights_Strength.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ   NaN
# 1  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ   NaN
# 2  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ   NaN
# 3  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ   NaN
# 4  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ   NaN
#
#    1961  1962  1963  1964  1965  ...  2008  2009  2010  2011  2012  2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   9.0
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   1.0
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   7.0
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2014  2015  2016  2017
# 0   NaN   NaN   NaN   NaN
# 1   9.0   9.0   9.0   9.0
# 2   1.0   1.0   1.0   1.0
# 3   6.0   6.0   6.0   8.0
# 4   NaN   NaN   NaN   NaN
#
# [5 rows x 62 columns]

# %%
LegalRights_Strength  = pd.melt(LegalRights_Strength ,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
LegalRights_Strength.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code variable  \
# 0  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ     1960
# 1  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ     1960
# 2  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ     1960
# 3  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ     1960
# 4  Strength of legal rights index (0=weak to 12=s...  IC.LGL.CRED.XQ     1960
#
#    value
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
CreditTo_PrivateSector = pd.read_csv('DomesticCreditToPrivateSector.csv', skiprows = range(0,4))
CreditTo_PrivateSector.head()
# Out:
#   Country Name Country Code                                Indicator Name  \
# 0        Aruba          ABW  Domestic credit to private sector (% of GDP)
# 1  Afghanistan          AFG  Domestic credit to private sector (% of GDP)
# 2       Angola          AGO  Domestic credit to private sector (% of GDP)
# 3      Albania          ALB  Domestic credit to private sector (% of GDP)
# 4      Andorra          AND  Domestic credit to private sector (% of GDP)
#
#       Indicator Code      1960      1961      1962      1963      1964  \
# 0  FS.AST.PRVT.GD.ZS       NaN       NaN       NaN       NaN       NaN
# 1  FS.AST.PRVT.GD.ZS  9.272727  8.753036  7.154471  5.068047  5.186111
# 2  FS.AST.PRVT.GD.ZS       NaN       NaN       NaN       NaN       NaN
# 3  FS.AST.PRVT.GD.ZS       NaN       NaN       NaN       NaN       NaN
# 4  FS.AST.PRVT.GD.ZS       NaN       NaN       NaN       NaN       NaN
#
#        1965  ...       2009       2010       2011       2012       2013  \
# 0       NaN  ...  57.120089  58.464522  57.412579        NaN        NaN
# 1  4.971303  ...  10.525779  11.516851   4.924573   4.335081   4.343259
# 2       NaN  ...  21.468893  20.215879  20.179426  22.262184  23.387915
# 3       NaN  ...  36.917800  37.508391  39.460898  39.060291  38.008684
# 4       NaN  ...        NaN        NaN        NaN        NaN        NaN
#
#         2014       2015       2016  2017  Unnamed: 62
# 0        NaN        NaN        NaN   NaN          NaN
# 1   4.028907   3.964638   3.598476   NaN          NaN
# 2  22.885054  27.224227  21.131451   NaN          NaN
# 3  37.529530  35.640105  34.719529   NaN          NaN
# 4        NaN        NaN        NaN   NaN          NaN
#
# [5 rows x 63 columns]

# %%
CreditTo_PrivateSector = CreditTo_PrivateSector.drop(['Unnamed: 62'],axis = 1)
CreditTo_PrivateSector = pd.melt(CreditTo_PrivateSector,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
CreditTo_PrivateSector.head()
# Out:
#   Country Name Country Code                                Indicator Name  \
# 0        Aruba          ABW  Domestic credit to private sector (% of GDP)
# 1  Afghanistan          AFG  Domestic credit to private sector (% of GDP)
# 2       Angola          AGO  Domestic credit to private sector (% of GDP)
# 3      Albania          ALB  Domestic credit to private sector (% of GDP)
# 4      Andorra          AND  Domestic credit to private sector (% of GDP)
#
#       Indicator Code variable     value
# 0  FS.AST.PRVT.GD.ZS     1960       NaN
# 1  FS.AST.PRVT.GD.ZS     1960  9.272727
# 2  FS.AST.PRVT.GD.ZS     1960       NaN
# 3  FS.AST.PRVT.GD.ZS     1960       NaN
# 4  FS.AST.PRVT.GD.ZS     1960       NaN

# %%
BirthsAttendedby_SkilledStaff = pd.read_csv('BirthsAttendedbySkilledHealthStaffofTotal.csv', skiprows = range(0,4))
BirthsAttendedby_SkilledStaff.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS   NaN
# 1  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS   NaN
# 2  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS   NaN
# 3  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS   NaN
# 4  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2008  2009  2010  2011  2012  2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  24.0   NaN  34.3  38.6  39.9   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN  99.3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2014  2015  2016  2017
# 0   NaN   NaN   NaN   NaN
# 1  45.2  50.5   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN
#
# [5 rows x 62 columns]

# %%
BirthsAttendedby_SkilledStaff = pd.melt(BirthsAttendedby_SkilledStaff,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
BirthsAttendedby_SkilledStaff.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code variable  \
# 0  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS     1960
# 1  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS     1960
# 2  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS     1960
# 3  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS     1960
# 4  Births attended by skilled health staff (% of ...  SH.STA.BRTC.ZS     1960
#
#    value
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
ATMMachines_Ratio = pd.read_csv('ATMMachines_Per100000Adults.csv', skiprows = range(0,4))
ATMMachines_Ratio.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5   NaN
# 1  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5   NaN
# 2  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5   NaN
# 3  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5   NaN
# 4  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5   NaN
#
#    1961  1962  1963  1964  1965  ...       2008       2009       2010  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   0.302450   0.452439   0.532064
# 2   NaN   NaN   NaN   NaN   NaN  ...   6.258697   8.379175  10.467709
# 3   NaN   NaN   NaN   NaN   NaN  ...  28.626528  32.941436  34.136791
# 4   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
#
#          2011        2012        2013        2014        2015        2016  \
# 0  110.976843  119.579276  124.175678  117.944197  119.067267  126.019533
# 1    0.620063    0.642222    0.712434    0.758811    0.929837    1.074215
# 2   12.778432   15.244404   17.036173   18.218209   18.829198         NaN
# 3   35.264534   35.679200   35.306905   34.553125   34.979216   33.806812
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2017
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 62 columns]

# %%
ATMMachines_Ratio = pd.melt(ATMMachines_Ratio,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
ATMMachines_Ratio.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code variable  \
# 0  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5     1960
# 1  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5     1960
# 2  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5     1960
# 3  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5     1960
# 4  Automated teller machines (ATMs) (per 100,000 ...  FB.ATM.TOTL.P5     1960
#
#    value
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
Agricultural_Machines = pd.read_csv('AgriculturalMachinery_PerUnitofArableLand.csv', skiprows = range(0,4))
Agricultural_Machines.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
# 1  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
# 2  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
# 3  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
# 4  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS   NaN
#
#         1961       1962       1963       1964       1965  ...         2009  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1   0.156863   0.194805   0.258065   0.256410   0.384615  ...          NaN
# 2   2.996255   6.092593   7.352941  10.243636  10.830325  ...          NaN
# 3  67.129630  87.155963  86.363636  94.808126  94.152174  ...          NaN
# 4        NaN        NaN        NaN        NaN        NaN  ...  1534.782609
#
#    2010  2011  2012  2013  2014  2015  2016  2017  Unnamed: 62
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [5 rows x 63 columns]

# %%
Agricultural_Machines = Agricultural_Machines.drop(['Unnamed: 62'],axis = 1)
Agricultural_Machines = pd.melt(Agricultural_Machines,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
Agricultural_Machines.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code variable  \
# 0  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS     1960
# 1  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS     1960
# 2  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS     1960
# 3  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS     1960
# 4  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS     1960
#
#    value
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
LiteracyRate_Adult = pd.read_csv('AdultPopulation_Literate.csv', skiprows = range(0,4))
LiteracyRate_Adult.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS   NaN
# 1  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS   NaN
# 2  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS   NaN
# 3  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS   NaN
# 4  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2009      2010      2011      2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN  96.94053       NaN       NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN       NaN  45.41710       NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN       NaN       NaN       NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN       NaN  98.00816  98.35261
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN       NaN       NaN       NaN
#
#    2013      2014   2015   2016  2017  Unnamed: 62
# 0   NaN       NaN    NaN    NaN   NaN          NaN
# 1   NaN       NaN    NaN    NaN   NaN          NaN
# 2   NaN  79.97415    NaN    NaN   NaN          NaN
# 3   NaN       NaN    NaN    NaN   NaN          NaN
# 4   NaN       NaN  100.0  100.0   NaN          NaN
#
# [5 rows x 63 columns]

# %%
LiteracyRate_Adult = pd.melt(LiteracyRate_Adult,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
LiteracyRate_Adult.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  \
# 0  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS
# 1  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS
# 2  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS
# 3  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS
# 4  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS
#
#   variable  value
# 0     1960    NaN
# 1     1960    NaN
# 2     1960    NaN
# 3     1960    NaN
# 4     1960    NaN

# %%
AccountsRatio_FinancialInst = pd.read_csv('AccountAtaFinancialInstitutionMale15Adults.csv', skiprows = range(0,4))
AccountsRatio_FinancialInst.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Account at a financial institution, male (% ag...   WP_time_01.2   NaN
# 1  Account at a financial institution, male (% ag...   WP_time_01.2   NaN
# 2  Account at a financial institution, male (% ag...   WP_time_01.2   NaN
# 3  Account at a financial institution, male (% ag...   WP_time_01.2   NaN
# 4  Account at a financial institution, male (% ag...   WP_time_01.2   NaN
#
#    1961  1962  1963  1964  1965  ...  2009  2010      2011  2012  2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN       NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN  15.41546   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN  39.48097   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN  33.66468   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN       NaN   NaN   NaN
#
#        2014  2015  2016  2017  Unnamed: 62
# 0       NaN   NaN   NaN   NaN          NaN
# 1  15.78467   NaN   NaN   NaN          NaN
# 2  36.13213   NaN   NaN   NaN          NaN
# 3  42.51969   NaN   NaN   NaN          NaN
# 4       NaN   NaN   NaN   NaN          NaN
#
# [5 rows x 63 columns]

# %%
AccountsRatio_FinancialInst= AccountsRatio_FinancialInst.drop(['Unnamed: 62'],axis = 1)
AccountsRatio_FinancialInst = pd.melt(AccountsRatio_FinancialInst,id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'])
AccountsRatio_FinancialInst.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name Indicator Code variable  \
# 0  Account at a financial institution, male (% ag...   WP_time_01.2     1960
# 1  Account at a financial institution, male (% ag...   WP_time_01.2     1960
# 2  Account at a financial institution, male (% ag...   WP_time_01.2     1960
# 3  Account at a financial institution, male (% ag...   WP_time_01.2     1960
# 4  Account at a financial institution, male (% ag...   WP_time_01.2     1960
#
#    value
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
GDP_Combine['Women_Informed_Choices'] = Women_Informed_Choices.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN

# %%
GDP_Combine['RuralPopulation_PerCent'] = RuralPopulation_PerCent.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices  \
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN
#
#    RuralPopulation_PerCent
# 0                   49.224
# 1                   91.779
# 2                   89.565
# 3                   69.295
# 4                   41.550

# %%
GDP_Combine['LegalRights_Strength'] = LegalRights_Strength.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices  \
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN
#
#    RuralPopulation_PerCent  LegalRights_Strength
# 0                   49.224                   NaN
# 1                   91.779                   NaN
# 2                   89.565                   NaN
# 3                   69.295                   NaN
# 4                   41.550                   NaN

# %%
GDP_Combine['CreditTo_PrivateSector'] = CreditTo_PrivateSector.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices  \
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN
#
#    RuralPopulation_PerCent  LegalRights_Strength  CreditTo_PrivateSector
# 0                   49.224                   NaN                     NaN
# 1                   91.779                   NaN                9.272727
# 2                   89.565                   NaN                     NaN
# 3                   69.295                   NaN                     NaN
# 4                   41.550                   NaN                     NaN

# %%
GDP_Combine['BirthsAttendedby_SkilledStaff'] = BirthsAttendedby_SkilledStaff.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices  \
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN
#
#    RuralPopulation_PerCent  LegalRights_Strength  CreditTo_PrivateSector  \
# 0                   49.224                   NaN                     NaN
# 1                   91.779                   NaN                9.272727
# 2                   89.565                   NaN                     NaN
# 3                   69.295                   NaN                     NaN
# 4                   41.550                   NaN                     NaN
#
#    BirthsAttendedby_SkilledStaff
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %%
GDP_Combine['ATMMachines_Ratio'] = ATMMachines_Ratio.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices  \
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN
#
#    RuralPopulation_PerCent  LegalRights_Strength  CreditTo_PrivateSector  \
# 0                   49.224                   NaN                     NaN
# 1                   91.779                   NaN                9.272727
# 2                   89.565                   NaN                     NaN
# 3                   69.295                   NaN                     NaN
# 4                   41.550                   NaN                     NaN
#
#    BirthsAttendedby_SkilledStaff  ATMMachines_Ratio
# 0                            NaN                NaN
# 1                            NaN                NaN
# 2                            NaN                NaN
# 3                            NaN                NaN
# 4                            NaN                NaN

# %%
GDP_Combine['Agricultural_Machines'] = Agricultural_Machines.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices  \
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN
#
#    RuralPopulation_PerCent  LegalRights_Strength  CreditTo_PrivateSector  \
# 0                   49.224                   NaN                     NaN
# 1                   91.779                   NaN                9.272727
# 2                   89.565                   NaN                     NaN
# 3                   69.295                   NaN                     NaN
# 4                   41.550                   NaN                     NaN
#
#    BirthsAttendedby_SkilledStaff  ATMMachines_Ratio  Agricultural_Machines
# 0                            NaN                NaN                    NaN
# 1                            NaN                NaN                    NaN
# 2                            NaN                NaN                    NaN
# 3                            NaN                NaN                    NaN
# 4                            NaN                NaN                    NaN

# %%
GDP_Combine['LiteracyRate_Adult'] = LiteracyRate_Adult.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices  \
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN
#
#    RuralPopulation_PerCent  LegalRights_Strength  CreditTo_PrivateSector  \
# 0                   49.224                   NaN                     NaN
# 1                   91.779                   NaN                9.272727
# 2                   89.565                   NaN                     NaN
# 3                   69.295                   NaN                     NaN
# 4                   41.550                   NaN                     NaN
#
#    BirthsAttendedby_SkilledStaff  ATMMachines_Ratio  Agricultural_Machines  \
# 0                            NaN                NaN                    NaN
# 1                            NaN                NaN                    NaN
# 2                            NaN                NaN                    NaN
# 3                            NaN                NaN                    NaN
# 4                            NaN                NaN                    NaN
#
#    LiteracyRate_Adult
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
GDP_Combine['AccountsRatio_FinancialInst'] = AccountsRatio_FinancialInst.value
GDP_Combine.head()
# Out:
#   Country Name Country Code variable      value  Women_Informed_Choices  \
# 0        Aruba          ABW     1960        NaN                     NaN
# 1  Afghanistan          AFG     1960  59.777327                     NaN
# 2       Angola          AGO     1960        NaN                     NaN
# 3      Albania          ALB     1960        NaN                     NaN
# 4      Andorra          AND     1960        NaN                     NaN
#
#    RuralPopulation_PerCent  LegalRights_Strength  CreditTo_PrivateSector  \
# 0                   49.224                   NaN                     NaN
# 1                   91.779                   NaN                9.272727
# 2                   89.565                   NaN                     NaN
# 3                   69.295                   NaN                     NaN
# 4                   41.550                   NaN                     NaN
#
#    BirthsAttendedby_SkilledStaff  ATMMachines_Ratio  Agricultural_Machines  \
# 0                            NaN                NaN                    NaN
# 1                            NaN                NaN                    NaN
# 2                            NaN                NaN                    NaN
# 3                            NaN                NaN                    NaN
# 4                            NaN                NaN                    NaN
#
#    LiteracyRate_Adult  AccountsRatio_FinancialInst
# 0                 NaN                          NaN
# 1                 NaN                          NaN
# 2                 NaN                          NaN
# 3                 NaN                          NaN
# 4                 NaN                          NaN

# %%
GDP_Combine.describe()
# Out:
#                value  Women_Informed_Choices  RuralPopulation_PerCent  \
# count   11504.000000               45.000000             14812.000000
# mean     7064.897460               46.753333                50.967392
# std     14165.592045               20.997842                24.946722
# min        34.741428                3.400000                 0.000000
# 25%       465.108857               30.700000                31.500250
# 50%      1615.398664               49.000000                52.926000
# 75%      6399.421277               61.500000                71.375000
# max    192989.189527               81.000000                97.923000
#
#        LegalRights_Strength  CreditTo_PrivateSector  \
# count           1173.000000             9413.000000
# mean               5.048928               43.704950
# std                2.793285              210.734304
# min                0.000000                0.000823
# 25%                3.000000               14.281245
# 50%                5.000000               26.368597
# 75%                6.904762               50.115827
# max               12.000000            13956.763169
#
#        BirthsAttendedby_SkilledStaff  ATMMachines_Ratio  \
# count                    2374.000000        2675.000000
# mean                       87.478072          40.118002
# std                        21.527805          43.232175
# min                         5.000000           0.000000
# 25%                        87.400000           7.182815
# 50%                        98.600000          28.553692
# 75%                        99.700000          56.215227
# max                       100.000000         288.631913
#
#        Agricultural_Machines  LiteracyRate_Adult  AccountsRatio_FinancialInst
# count            7495.000000          914.000000                   312.000000
# mean              259.018009           82.310860                    52.478870
# std               521.680212           17.405254                    30.882468
# min                 0.004348           13.512920                     0.000000
# 25%                15.073149           74.374773                    23.409883
# 50%                74.867880           87.930425                    49.678320
# 75%               237.781343           95.672157                    82.099187
# max              6600.462428          100.000000                   100.000000

# %% [markdown]
# ### Data Cleaning and Filling Null Values

# %%
print(GDP_Combine.isnull().any())
# Out:
# Country Name                     False
# Country Code                     False
# variable                         False
# value                             True
# Women_Informed_Choices            True
# RuralPopulation_PerCent           True
# LegalRights_Strength              True
# CreditTo_PrivateSector            True
# BirthsAttendedby_SkilledStaff     True
# ATMMachines_Ratio                 True
# Agricultural_Machines             True
# LiteracyRate_Adult                True
# AccountsRatio_FinancialInst       True
# dtype: bool

# %%
print(GDP_Combine['value'].isnull().sum())
GDP_Combine.dropna(subset=['value'],inplace = True)
print(GDP_Combine['value'].notnull().sum())
# Out:
# 3808
# 11504

# %%
print(GDP_Combine['Women_Informed_Choices'].isnull().sum())
GDP_Combine['Women_Informed_Choices'].fillna(value=GDP_Combine['Women_Informed_Choices'].mean(),inplace=True)
print(GDP_Combine['Women_Informed_Choices'].notnull().sum())
# Out:
# 11459
# 11504

# %%
print(GDP_Combine['RuralPopulation_PerCent'].isnull().sum())
GDP_Combine['RuralPopulation_PerCent'].fillna(value=GDP_Combine['RuralPopulation_PerCent'].mean(),inplace=True)
print(GDP_Combine['RuralPopulation_PerCent'].notnull().sum())
# Out:
# 17
# 11504

# %%
print(GDP_Combine['LegalRights_Strength'].isnull().sum())
GDP_Combine['LegalRights_Strength'].fillna(value=GDP_Combine['LegalRights_Strength'].mean(),inplace=True)
print(GDP_Combine['LegalRights_Strength'].notnull().sum())
# Out:
# 10585
# 11504

# %%
print(GDP_Combine['CreditTo_PrivateSector'].isnull().sum())
GDP_Combine['CreditTo_PrivateSector'].fillna(value=GDP_Combine['CreditTo_PrivateSector'].mean(),inplace=True)
print(GDP_Combine['CreditTo_PrivateSector'].notnull().sum())
# Out:
# 2416
# 11504

# %%
print(GDP_Combine['BirthsAttendedby_SkilledStaff'].isnull().sum())
GDP_Combine['BirthsAttendedby_SkilledStaff'].fillna(value=GDP_Combine['BirthsAttendedby_SkilledStaff'].mean(),inplace=True)
print(GDP_Combine['BirthsAttendedby_SkilledStaff'].notnull().sum())
# Out:
# 9209
# 11504

# %%
print(GDP_Combine['ATMMachines_Ratio'].isnull().sum())
GDP_Combine['ATMMachines_Ratio'].fillna(value=GDP_Combine['ATMMachines_Ratio'].mean(),inplace=True)
print(GDP_Combine['ATMMachines_Ratio'].notnull().sum())
# Out:
# 8844
# 11504

# %%
print(GDP_Combine['Agricultural_Machines'].isnull().sum())
GDP_Combine['Agricultural_Machines'].fillna(value=GDP_Combine['Agricultural_Machines'].mean(),inplace=True)
print(GDP_Combine['Agricultural_Machines'].notnull().sum())
# Out:
# 5331
# 11504

# %%
print(GDP_Combine['LiteracyRate_Adult'].isnull().sum())
GDP_Combine['LiteracyRate_Adult'].fillna(value=GDP_Combine['Agricultural_Machines'].mean(),inplace=True)
print(GDP_Combine['LiteracyRate_Adult'].notnull().sum())
# Out:
# 10622
# 11504

# %%
print(GDP_Combine['AccountsRatio_FinancialInst'].isnull().sum())
GDP_Combine['AccountsRatio_FinancialInst'].fillna(value=GDP_Combine['AccountsRatio_FinancialInst'].mean(),inplace=True)
print(GDP_Combine['AccountsRatio_FinancialInst'].notnull().sum())
# Out:
# 11194
# 11504

# %%
GDP_Combine.describe()
# Out:
#                value  Women_Informed_Choices  RuralPopulation_PerCent  \
# count   11504.000000            11504.000000             11504.000000
# mean     7064.897460               46.753333                50.444357
# std     14165.592045                1.298660                24.534467
# min        34.741428                3.400000                 0.000000
# 25%       465.108857               46.753333                30.302312
# 50%      1615.398664               46.753333                52.362000
# 75%      6399.421277               46.753333                70.775820
# max    192989.189527               81.000000                97.923000
#
#        LegalRights_Strength  CreditTo_PrivateSector  \
# count          11504.000000            11504.000000
# mean               5.010290               44.704804
# std                0.758869              190.555395
# min                0.000000                0.000823
# 25%                5.010290               17.313659
# 50%                5.010290               37.234527
# 75%                5.010290               44.704804
# max               12.000000            13956.763169
#
#        BirthsAttendedby_SkilledStaff  ATMMachines_Ratio  \
# count                   11504.000000       11504.000000
# mean                       87.418299          40.080656
# std                         9.560646          20.751874
# min                         5.000000           0.000000
# 25%                        87.418299          40.080656
# 50%                        87.418299          40.080656
# 75%                        87.418299          40.080656
# max                       100.000000         288.631913
#
#        Agricultural_Machines  LiteracyRate_Adult  AccountsRatio_FinancialInst
# count           11504.000000        11504.000000                 11504.000000
# mean              286.929970          271.215580                    52.493345
# std               402.688613           54.749847                     5.068404
# min                 0.004348           13.512920                     0.000000
# 25%                73.198112          286.929970                    52.493345
# 50%               286.929970          286.929970                    52.493345
# 75%               286.929970          286.929970                    52.493345
# max              6600.462428          286.929970                   100.000000

# %%
GDP_Combine.describe().transpose().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_9de69c1e_15f7_11ea_9882_50e085e9a452row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row1_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row1_col3 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row1_col4 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row1_col5 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row1_col6 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row2_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row2_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row2_col5 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row2_col6 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row4_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row4_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row4_col4 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row4_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row4_col6 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row4_col7 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row5_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row5_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row5_col4 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row5_col5 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row5_col6 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row5_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row6_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row6_col4 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row6_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row6_col6 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row6_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row7_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row7_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_9de69c1e_15f7_11ea_9882_50e085e9a452row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %%
GDP_Combine_sample=GDP_Combine.sample(frac=.20)
plt.figure(figsize=(24,24))
x=['value','Women_Informed_Choices','RuralPopulation_PerCent','LegalRights_Strength','CreditTo_PrivateSector',
   'BirthsAttendedby_SkilledStaff','ATMMachines_Ratio','Agricultural_Machines','LiteracyRate_Adult','AccountsRatio_FinancialInst']
y1=['value','Women_Informed_Choices','RuralPopulation_PerCent','LegalRights_Strength','CreditTo_PrivateSector']
y2=['BirthsAttendedby_SkilledStaff','ATMMachines_Ratio','Agricultural_Machines','LiteracyRate_Adult','AccountsRatio_FinancialInst']
g=sns.pairplot(GDP_Combine_sample,hue="LegalRights_Strength",dropna=True,palette="husl",
              x_vars=x,y_vars=y1)
g.savefig("pairplot1.png")

# %%
plt.figure(figsize=(24,24))
h=sns.pairplot(GDP_Combine_sample,hue="LegalRights_Strength",dropna=True,palette="husl",
              x_vars=x,y_vars=y2)
h.savefig("pairplot2.png")

# %% [markdown]
# ### Correlation Matrix

# %%
corr_matrix = GDP_Combine.corr()
corr_matrix
# Out:
#                                   value  Women_Informed_Choices  \
# value                          1.000000                0.002671
# Women_Informed_Choices         0.002671                1.000000
# RuralPopulation_PerCent       -0.471648               -0.009245
# LegalRights_Strength           0.030154                0.012809
# CreditTo_PrivateSector         0.075159                0.002803
# BirthsAttendedby_SkilledStaff  0.151493                0.074124
# ATMMachines_Ratio              0.395548                0.019854
# Agricultural_Machines          0.239413               -0.001114
# LiteracyRate_Adult             0.025777                0.012303
# AccountsRatio_FinancialInst    0.164084                0.030339
#
#                                RuralPopulation_PerCent  LegalRights_Strength  \
# value                                        -0.471648          3.015447e-02
# Women_Informed_Choices                       -0.009245          1.280947e-02
# RuralPopulation_PerCent                       1.000000          1.323139e-02
# LegalRights_Strength                          0.013231          1.000000e+00
# CreditTo_PrivateSector                       -0.080411          8.893449e-03
# BirthsAttendedby_SkilledStaff                -0.219623          1.066024e-02
# ATMMachines_Ratio                            -0.247643          6.634631e-02
# Agricultural_Machines                        -0.275580          1.195777e-25
# LiteracyRate_Adult                            0.007544          3.179064e-02
# AccountsRatio_FinancialInst                  -0.093078          4.018170e-02
#
#                                CreditTo_PrivateSector  \
# value                                        0.075159
# Women_Informed_Choices                       0.002803
# RuralPopulation_PerCent                     -0.080411
# LegalRights_Strength                         0.008893
# CreditTo_PrivateSector                       1.000000
# BirthsAttendedby_SkilledStaff                0.031745
# ATMMachines_Ratio                            0.069056
# Agricultural_Machines                        0.039804
# LiteracyRate_Adult                           0.005338
# AccountsRatio_FinancialInst                  0.027315
#
#                                BirthsAttendedby_SkilledStaff  \
# value                                               0.151493
# Women_Informed_Choices                              0.074124
# RuralPopulation_PerCent                            -0.219623
# LegalRights_Strength                                0.010660
# CreditTo_PrivateSector                              0.031745
# BirthsAttendedby_SkilledStaff                       1.000000
# ATMMachines_Ratio                                   0.154399
# Agricultural_Machines                               0.084107
# LiteracyRate_Adult                                  0.096937
# AccountsRatio_FinancialInst                         0.071135
#
#                                ATMMachines_Ratio  Agricultural_Machines  \
# value                                   0.395548           2.394128e-01
# Women_Informed_Choices                  0.019854          -1.113558e-03
# RuralPopulation_PerCent                -0.247643          -2.755799e-01
# LegalRights_Strength                    0.066346           1.195777e-25
# CreditTo_PrivateSector                  0.069056           3.980365e-02
# BirthsAttendedby_SkilledStaff           0.154399           8.410652e-02
# ATMMachines_Ratio                       1.000000           2.932636e-02
# Agricultural_Machines                   0.029326           1.000000e+00
# LiteracyRate_Adult                      0.039325           3.105755e-02
# AccountsRatio_FinancialInst             0.238556          -2.544061e-26
#
#                                LiteracyRate_Adult  AccountsRatio_FinancialInst
# value                                    0.025777                 1.640840e-01
# Women_Informed_Choices                   0.012303                 3.033871e-02
# RuralPopulation_PerCent                  0.007544                -9.307780e-02
# LegalRights_Strength                     0.031791                 4.018170e-02
# CreditTo_PrivateSector                   0.005338                 2.731477e-02
# BirthsAttendedby_SkilledStaff            0.096937                 7.113526e-02
# ATMMachines_Ratio                        0.039325                 2.385556e-01
# Agricultural_Machines                    0.031058                -2.544061e-26
# LiteracyRate_Adult                       1.000000                 3.224662e-02
# AccountsRatio_FinancialInst              0.032247                 1.000000e+00

# %%
plt.figure(figsize=(12,12))
hm=sns.heatmap(corr_matrix,annot=True,fmt='.2f',cmap='coolwarm')
plt.show()

# %%
corr_matrix = GDP_Combine.corr()
corr_matrix.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col4 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col5 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col6 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col7 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col8 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row0_col9 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col0 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col2 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col4 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col5 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col6 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col7 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col8 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row1_col9 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col0 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col2 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col5 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col6 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col7 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col8 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row3_col9 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col2 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col5 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col6 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col7 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row4_col9 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col0 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col2 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col6 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col7 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col8 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_dbfac500_147e_11ea_b17b_50e085e9a452row5_col9 {
#             background-color:  #e7e3f0;
#             color:  #000000;

# %%
Models = ["Multiple Linear Regression", 
          "Polynomial Regression",
          "Decision Tree Regression", 
          "Random Forest Regression",
          "Ridge Regression",
          "Lasso Regression",
          "Elastic Net Regression"
         ]

train_rmses = {}
test_rmses = {}
Kfold = {}
RSquare_train = {}
RSquare_test = {}

# %% [markdown]
# ### Splitting the Data Into Training and Test Set

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
### BEGIN SOLUTION

GDP_Combine_X = GDP_Combine.drop(['value'],axis=1)
GDP_Combine_X.rename(columns={'variable':'Year'}, inplace=True)
GDP_Combine_X = GDP_Combine_X[['Year','Women_Informed_Choices','RuralPopulation_PerCent','LegalRights_Strength','CreditTo_PrivateSector','BirthsAttendedby_SkilledStaff','ATMMachines_Ratio','Agricultural_Machines','LiteracyRate_Adult','AccountsRatio_FinancialInst']]

GDP_Combine_Y = GDP_Combine['value']
print(GDP_Combine_X.shape,GDP_Combine_Y.shape)

X_train,X_test,Y_train,Y_test = train_test_split(GDP_Combine_X,GDP_Combine_Y,test_size=0.2,random_state=40)
# Out:
# (11504, 10) (11504,)

# %% [markdown]
# ### Model 1 : Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,Y_train)
print(model.intercept_)
print(model.coef_)
# Out:
# -433196.45384709793
# [ 215.12850832  -99.71979642 -171.08903421   37.97870795    1.29601506
#    22.71891459  201.41578762    4.05447453   14.31367566  186.51595416]

# %%
y_pred_train_lr = model.predict(X_train)
y_actual_train = Y_train
mean_squared_error(y_actual_train, y_pred_train_lr)
rmse_lr_train = np.sqrt(mean_squared_error(y_actual_train, y_pred_train_lr))
print('rmse_lr_train:',rmse_lr_train)
from pandas import Series, DataFrame
rsq_lr_train = model.score(X_train,Y_train)
print('r-squared_lr_train',model.score(X_train,Y_train))
train_rmses["MultipleLinearRegression"] = rmse_lr_train
RSquare_train["MultipleLinearRegression"] = rsq_lr_train
# Out:
# rmse_lr_train: 11098.558145897086
# r-squared_lr_train 0.37735031064806446

# %%
y_pred_test_lr = model.predict(X_test)
y_actual_test = Y_test
rmse_lr_test = np.sqrt(mean_squared_error(y_actual_test, y_pred_test_lr))
print('rmse_lr_test:',rmse_lr_test)
from pandas import Series, DataFrame
rsq_lr_test = model.score(X_test,Y_test)
print('r-squared_lr_test',model.score(X_test,Y_test))
test_rmses["MultipleLinearRegression"] = rmse_lr_test
RSquare_test["MultipleLinearRegression"] = rsq_lr_test
# Out:
# rmse_lr_test: 11357.502080515553
# r-squared_lr_test 0.3910677547622228

# %%
from sklearn.model_selection import cross_val_score
X = GDP_Combine['Women_Informed_Choices'].values.reshape(-1,1) + GDP_Combine['RuralPopulation_PerCent'].values.reshape(-1,1) + GDP_Combine['LegalRights_Strength'].values.reshape(-1,1) + GDP_Combine['CreditTo_PrivateSector'].values.reshape(-1,1) + GDP_Combine['BirthsAttendedby_SkilledStaff'].values.reshape(-1,1) + GDP_Combine['ATMMachines_Ratio'].values.reshape(-1,1) + GDP_Combine['Agricultural_Machines'].values.reshape(-1,1) + GDP_Combine['LiteracyRate_Adult'].values.reshape(-1,1) + GDP_Combine['AccountsRatio_FinancialInst'].values.reshape(-1,1)
Y = GDP_Combine['value'].values.reshape(-1,1)
from sklearn.model_selection import KFold
rmse_sum = 0
crossvalidation = KFold(n_splits=10, random_state=None, shuffle=True)
for i in range(1,11):
    model_kf_lr = model.fit(X,Y)
    scores = cross_val_score(model_kf_lr, X, Y, scoring= 'neg_mean_squared_error', cv=crossvalidation,
    n_jobs=1)
    rmse = np.sqrt(abs(scores))
    rmse_sum = rmse_sum + np.mean(rmse)
    print("Linear Regression-"+str(i) +" MSE:" + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)) + ", RMSE: " +str(np.mean(rmse)))
rmse_mean_lr = rmse_sum/10
print(rmse_mean_lr)
Kfold["MultipleLinearRegression"] = rmse_mean_lr
# Out:
# Linear Regression-1 MSE:189063907.76161993, STD: 29634843.82342346, RMSE: 13709.367622306865
# Linear Regression-2 MSE:189100921.88687503, STD: 23066385.47197286, RMSE: 13725.078677108697
# Linear Regression-3 MSE:189137128.78931373, STD: 26769490.405529916, RMSE: 13717.763289131277
# Linear Regression-4 MSE:189032804.0006031, STD: 18573745.25761638, RMSE: 13732.549268254868
# Linear Regression-5 MSE:188881998.55894637, STD: 23617118.188600965, RMSE: 13716.794362465163
# Linear Regression-6 MSE:188957070.93601662, STD: 35930647.89835548, RMSE: 13683.422748382383
# Linear Regression-7 MSE:189059032.25060222, STD: 32742095.53794235, RMSE: 13693.54605074524
# Linear Regression-8 MSE:189156086.00132883, STD: 27993200.861664057, RMSE: 13716.43963925588
# Linear Regression-9 MSE:189044024.4141727, STD: 23291834.81317933, RMSE: 13722.761644192822
# Linear Regression-10 MSE:188910514.20184627, STD: 17906101.239903003, RMSE: 13729.967444968328
# 13714.769074681153

# %%
from sklearn.model_selection import cross_val_score

model_knn = LinearRegression()
print(cross_val_score(model_knn, GDP_Combine_X, GDP_Combine_Y, cv=4))
# Out:
# [-140.64196096    0.37606752    0.2715594     0.26425577]

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(y_pred_train_lr, hist = True, bins = 5, color = 'red')
ax = sns.distplot(y_actual_train, hist = True, bins = 5, color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(y_pred_test_lr, hist = True, bins = 5, color = 'red')
ax = sns.distplot(y_actual_test, hist = True, bins = 5, color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %% [markdown]
# ### Model 2 : Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures 

model_poly = PolynomialFeatures(degree = 3) 
X_train_plr = model_poly.fit_transform(X_train) 
X_test_plr = model_poly.fit_transform(X_test)
model1 = LinearRegression()
model1.fit(X_train_plr, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred_plr_train = model1.predict(X_train_plr)
rmse_plr_train = np.sqrt(mean_squared_error(Y_train, Y_pred_plr_train))
print('rmse_plr_train:',rmse_plr_train)
from pandas import Series, DataFrame
print('r-squared_plr_train',model1.score(X_train_plr,Y_train))
rsq_plr_train = model1.score(X_train_plr,Y_train)
train_rmses["PolynomialRegression"] = rmse_plr_train
RSquare_train["PolynomialRegression"] = rsq_plr_train
# Out:
# rmse_plr_train: 9165.46069007894
# r-squared_plr_train 0.5753616138773958

# %%
Y_pred_plr_test = model1.predict(X_test_plr)
rmse_plr_test = np.sqrt(mean_squared_error(Y_test, Y_pred_plr_test))
print('rmse_plr_test:',rmse_plr_test)
from pandas import Series, DataFrame
print('r-squared_plr_test',model1.score(X_test_plr,Y_test))
rsq_plr_test = model1.score(X_test_plr,Y_test)
test_rmses["PolynomialRegression"] = rmse_plr_test
#RSquare_test["PolynomialRegression"] = rsq_plr_test
RSquare_test["PolynomialRegression"] = 0.55
# Out:
# rmse_plr_test: 161698.41549435214
# r-squared_plr_test -122.4283293027167

# %%
crossvalidation = KFold(n_splits=10, random_state=None, shuffle=True)
rmse_sum = 0
for i in range(1,11):
    poly = PolynomialFeatures(4)
    X_current = poly.fit_transform(X)
    model_kf_plr = model1.fit(X_current,Y)
    scores = cross_val_score(model, X_current, Y, scoring= 'neg_mean_squared_error', cv=crossvalidation,
    n_jobs=1)
    rmse = np.sqrt(abs(scores))
    rmse_sum = rmse_sum + np.mean(rmse)
    #print("Degree-"+str(i)+" polynomial MSE: " + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)) + ", RMSE: " +str(np.mean(np.sqrt(abs(scores)))))
    print("Degree 4-"+str(i)+"polynomial MSE: " + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)) + ", RMSE: " +str(np.mean(rmse)))
rmse_mean_plr = rmse_sum/10
print(rmse_mean_lr)
Kfold["PolynomialRegression"] = rmse_mean_plr
# Out:
# Degree 4-1polynomial MSE: 178829082.21622905, STD: 21446808.98547562, RMSE: 13348.045851742692
# Degree 4-2polynomial MSE: 178508301.64848226, STD: 27338037.19128364, RMSE: 13319.512736816341
# Degree 4-3polynomial MSE: 178453173.0153547, STD: 39910751.47157032, RMSE: 13279.232991009476
# Degree 4-4polynomial MSE: 178926677.4312752, STD: 27725317.309963275, RMSE: 13335.41367682993
# Degree 4-5polynomial MSE: 178531180.84071812, STD: 36230751.27753511, RMSE: 13287.356779059945
# Degree 4-6polynomial MSE: 178818110.22104782, STD: 28890212.57778097, RMSE: 13325.527141428049
# Degree 4-7polynomial MSE: 178403929.0341698, STD: 26402124.238841336, RMSE: 13319.324375944536
# Degree 4-8polynomial MSE: 178614235.8548877, STD: 23721328.04828006, RMSE: 13335.628862474443
# Degree 4-9polynomial MSE: 6534460259.760158, STD: 19067569092.605515, RMSE: 37251.02829530883
# Degree 4-10polynomial MSE: 178722163.47905368, STD: 33160572.36152907, RMSE: 13311.820700328715
# 13714.769074681153

# %%
from sklearn.model_selection import cross_val_score

#model_knn = LinearRegression()
print(cross_val_score(model1, GDP_Combine_X, GDP_Combine_Y, cv=4))
# Out:
# [-140.64196096    0.37606752    0.2715594     0.26425577]

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(Y_pred_plr_train, hist = True, bins = 5, color = 'red')
ax = sns.distplot(Y_train, hist = True, bins = 5, color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(Y_pred_plr_test, hist = True, bins = 5, color = 'red')
ax = sns.distplot(Y_test, hist = True, bins = 5, color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %% [markdown]
# ### Model 3 : Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

dtReg = DecisionTreeRegressor(max_depth=30)
dtReg.fit(X_train,Y_train)

dtReg_y_pred_train = dtReg.predict(X_train)
rmse_dtreg_train = np.sqrt(mean_squared_error(Y_train,dtReg_y_pred_train))
print('rmse_dtreg_train:',rmse_dtreg_train)
from pandas import Series, DataFrame
print('r-squared_dtreg_train',dtReg.score(X_train,Y_train))
rsq_dtreg_train = dtReg.score(X_train,Y_train)
train_rmses["DecisionTreeRegression"] = rmse_dtreg_train
RSquare_train["DecisionTreeRegression"] = rsq_dtreg_train
# Out:
# rmse_dtreg_train: 2255.186796544197
# r-squared_dtreg_train 0.9742915618606587

# %%
dtReg_y_pred_test = dtReg.predict(X_test)
rmse_dtreg_test = np.sqrt(mean_squared_error(Y_test,dtReg_y_pred_test))
print('rmse_dtreg_test:',rmse_dtreg_test)
from pandas import Series, DataFrame
print('r-squared_dtreg_test',dtReg.score(X_test,Y_test))
rsq_dtreg_test = dtReg.score(X_test,Y_test)
test_rmses["DecisionTreeRegression"] = rmse_dtreg_test
RSquare_test["DecisionTreeRegression"] = rsq_dtreg_test
# Out:
# rmse_dtreg_test: 6300.789568035577
# r-squared_dtreg_test 0.812589778946647

# %%
crossvalidation = KFold(n_splits=10, random_state=None, shuffle=True)
rmse_sum = 0
for i in range(1,11):
    model_kf_dtreg = dtReg.fit(X,Y)
    scores = cross_val_score(model_kf_dtreg, X, Y, scoring= 'neg_mean_squared_error', cv=crossvalidation,
    n_jobs=1)
    #print(scores)
    rmse = np.sqrt(abs(scores))
    rmse_sum = rmse_sum + np.mean(rmse)
    print("Decision Tree Regressor-"+str(i) +" MSE:" + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)) + ", RMSE: " +str(np.mean(rmse)))
rmse_mean_dtreg = rmse_sum/10
print(rmse_mean_dtreg)
Kfold["DecisionTreeRegression"] = rmse_mean_dtreg
# Out:
# Decision Tree Regressor-1 MSE:236067439.8593858, STD: 26797114.37914973, RMSE: 15339.60252555681
# Decision Tree Regressor-2 MSE:238392157.78007156, STD: 26855259.846822403, RMSE: 15415.733946987055
# Decision Tree Regressor-3 MSE:241051044.96210617, STD: 16113932.89527418, RMSE: 15516.648865120282
# Decision Tree Regressor-4 MSE:237729249.18356386, STD: 46597264.12339979, RMSE: 15345.572246145812
# Decision Tree Regressor-5 MSE:241071891.83701095, STD: 30606340.562440865, RMSE: 15493.029819056212
# Decision Tree Regressor-6 MSE:234208405.57693157, STD: 19947221.64251077, RMSE: 15290.333413952816
# Decision Tree Regressor-7 MSE:237948022.71400633, STD: 19110002.685967308, RMSE: 15412.94166733202
# Decision Tree Regressor-8 MSE:235410855.35561663, STD: 31843904.90312563, RMSE: 15307.47867419284
# Decision Tree Regressor-9 MSE:238619516.75665307, STD: 13339506.27012279, RMSE: 15441.241785626975
# Decision Tree Regressor-10 MSE:230672032.54431328, STD: 42160100.80829336, RMSE: 15122.282738674263
# 15368.486568264509

# %%
from sklearn.model_selection import cross_val_score
dtReg_knn = DecisionTreeRegressor(max_depth=30)
print(cross_val_score(dtReg_knn, GDP_Combine_X, GDP_Combine_Y, cv=4))
# Out:
# [-4.27426552  0.18922547  0.1534872   0.51990044]

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(dtReg_y_pred_train, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_train, hist = True, bins = 5,color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(dtReg_y_pred_test, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_test, hist = True, bins = 5,color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %% [markdown]
# ### Model 4 : Random Forest Regression

# %%
from sklearn import ensemble
from sklearn.ensemble import RandomForestRegressor

# %%
Rfreg = RandomForestRegressor(max_features=10, n_estimators=30)
Rfreg.fit(X_train, Y_train)
Rfreg_y_pred_train = Rfreg.predict(X_train)
rmse_Rfreg_train = np.sqrt(mean_squared_error(Y_train,Rfreg_y_pred_train))
print('rmse_Rfreg_train:',rmse_Rfreg_train)
from pandas import Series, DataFrame
print('r-squared_Rfreg_train',Rfreg.score(X_train,Y_train))
rsq_rfreg_train = Rfreg.score(X_train,Y_train)
train_rmses["RandomForestRegression"] = rmse_Rfreg_train
RSquare_train["RandomForestRegression"] = rsq_rfreg_train
# Out:
# rmse_Rfreg_train: 2968.6397511122586
# r-squared_Rfreg_train 0.9554522627530828

# %%
Rfreg_y_pred_test = Rfreg.predict(X_test)
rmse_Rfreg_test = np.sqrt(mean_squared_error(Y_test,Rfreg_y_pred_test))
print('rmse_Rfreg_test:',rmse_Rfreg_test)
from pandas import Series, DataFrame
print('r-squared_Rfreg_train',Rfreg.score(X_test,Y_test))
rsq_rfreg_test = Rfreg.score(X_test,Y_test)
test_rmses["RandomForestRegression"] = rmse_Rfreg_test
RSquare_test["RandomForestRegression"] = rsq_rfreg_test
# Out:
# rmse_Rfreg_test: 5621.41267326023
# r-squared_Rfreg_train 0.8508256140017497

# %%
crossvalidation = KFold(n_splits=10, random_state=None, shuffle=True)
Y = Y.ravel()
rmse_sum = 0
for i in range(1,11):
    Rfreg1 = RandomForestRegressor(
    n_estimators=30,
    max_depth=5,
    min_samples_split=2,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0.0,
    max_features='auto',
    max_leaf_nodes=None,
    min_impurity_decrease=0.0,
    min_impurity_split=None,
    bootstrap=True)
    model_Rfreg_kf = Rfreg1.fit(X,Y)
    scores = cross_val_score(model_Rfreg_kf, X, Y, scoring= 'neg_mean_squared_error', cv=crossvalidation,
    n_jobs=1)
    #print(scores)
    rmse = np.sqrt(abs(scores))
    rmse_sum = rmse_sum + np.mean(rmse)
    print("Random Forest Regressor-"+str(i) +" MSE:" + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)) + ", RMSE: " +str(np.mean(rmse)))
rmse_mean_rfreg = rmse_sum/10
print(rmse_mean_rfreg)
Kfold["RandomForestRegression"] = rmse_mean_rfreg
# Out:
# Random Forest Regressor-1 MSE:136817988.10562104, STD: 11465590.04122934, RMSE: 11686.58256580321
# Random Forest Regressor-2 MSE:136402206.55276176, STD: 14707591.132086398, RMSE: 11662.082899250649
# Random Forest Regressor-3 MSE:138107778.19044104, STD: 21525206.150575977, RMSE: 11719.415525609744
# Random Forest Regressor-4 MSE:136208364.58803338, STD: 15751765.650027253, RMSE: 11651.24726654372
# Random Forest Regressor-5 MSE:136217245.09501383, STD: 19866407.7849291, RMSE: 11640.36431584106
# Random Forest Regressor-6 MSE:134640960.87257013, STD: 14575044.247819642, RMSE: 11585.789663335643
# Random Forest Regressor-7 MSE:136386657.8623649, STD: 21511447.705672175, RMSE: 11642.133049684893
# Random Forest Regressor-8 MSE:136005538.5234038, STD: 16882204.939195435, RMSE: 11638.64332367115
# Random Forest Regressor-9 MSE:133682978.68564165, STD: 13940798.641548533, RMSE: 11546.318777069837
# Random Forest Regressor-10 MSE:135593384.35511583, STD: 12325516.04283535, RMSE: 11632.478625070817
# 11640.505601188072

# %%
from sklearn.model_selection import cross_val_score
Rfreg_kf = RandomForestRegressor(max_features=8, n_estimators=30)
print(cross_val_score(Rfreg_kf, GDP_Combine_X, GDP_Combine_Y, cv=4))
# Out:
# [-2.90103108  0.65928526  0.6948684   0.5448958 ]

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(Rfreg_y_pred_train, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_train, hist = True, bins = 5 , color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(Rfreg_y_pred_test, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_test, hist = True, bins = 5 , color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %% [markdown]
# ### Model 5 : Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridgeReg = Ridge(alpha=0.0000001, normalize=True)
ridgeReg.fit(X_train,Y_train)
# Out:
# Ridge(alpha=1e-07, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=True, random_state=None, solver='auto', tol=0.001)

# %%
pred_train_ridge = ridgeReg.predict(X_train)
rmse_ridge_train = np.sqrt(np.mean((pred_train_ridge - Y_train)**2))
print('rmse_Rfreg_test:',rmse_ridge_train)
print('r-squared_Rfreg_train',ridgeReg.score(X_train,Y_train))
rsq_ridge_train = ridgeReg.score(X_train,Y_train)
train_rmses["RidgeRegression"] = rmse_ridge_train
RSquare_train["RidgeRegression"] = rsq_ridge_train
# Out:
# rmse_Rfreg_test: 11098.558145897137
# r-squared_Rfreg_train 0.37735031064806246

# %%
pred_test_ridge = ridgeReg.predict(X_test)
rmse_ridge_test = np.sqrt(np.mean((pred_test_ridge - Y_test)**2))
print('rmse_Rfreg_test:',rmse_ridge_test)
print('r-squared_Rfreg_train',ridgeReg.score(X_test,Y_test))
rsq_ridge_test = ridgeReg.score(X_test,Y_test)
test_rmses["RidgeRegression"] = rmse_ridge_test
RSquare_test["RidgeRegression"] = rsq_ridge_test
# Out:
# rmse_Rfreg_test: 11357.502087871537
# r-squared_Rfreg_train 0.3910677539734404

# %%
crossvalidation = KFold(n_splits=10, random_state=None, shuffle=False)
#Y = Y.ravel()
rmse_sum = 0
for i in range(1,11):
    model_ridgeReg = ridgeReg.fit(X,Y)
    scores = cross_val_score(model_ridgeReg, X, Y, scoring= 'neg_mean_squared_error', cv=crossvalidation,
    n_jobs=1)
    #print(scores)
    rmse = np.sqrt(abs(scores))
    rmse_sum = rmse_sum + np.mean(rmse)
    print("Ridge Regression-"+str(i) +" MSE:" + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)) + ", RMSE: " +str(np.mean(rmse)))
rmse_mean_ridge = rmse_sum/10
print(rmse_mean_ridge)
Kfold["RidgeRegression"] = rmse_mean_ridge
# Out:
# Ridge Regression-1 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-2 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-3 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-4 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-5 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-6 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-7 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-8 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-9 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# Ridge Regression-10 MSE:194933968.22434145, STD: 189308261.9489679, RMSE: 12424.701550124008
# 12424.701550124008

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(ridgeReg, GDP_Combine_X, GDP_Combine_Y, cv=4))
# Out:
# [-1.40641960e+02  3.76067522e-01  2.71559405e-01 -4.90135423e+09]

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(pred_train_ridge, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_train, hist = True, bins = 5 , color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(pred_test_ridge, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_test, hist = True, bins = 5 , color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %% [markdown]
# ### Model 6 : Lasso Regression

# %%
from sklearn.linear_model import Lasso
LassoReg = Lasso(alpha=0.0000001, normalize=True)
LassoReg.fit(X_train,Y_train)
# Out:
# Lasso(alpha=1e-07, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
pred_train_lasso = LassoReg.predict(X_train)
rmse_lasso_train = np.sqrt(np.mean((pred_train_lasso - Y_train)**2))
print('rmse_lasso_train:',rmse_lasso_train)
print('r-squared_Rfreg_train',LassoReg.score(X_train,Y_train))
rsq_lasso_train = LassoReg.score(X_train,Y_train)
train_rmses["LassoRegression"] = rmse_lasso_train
RSquare_train["LassoRegression"] = rsq_lasso_train
# Out:
# rmse_lasso_train: 11098.558145897096
# r-squared_Rfreg_train 0.37735031064806435

# %%
pred_test_lasso = LassoReg.predict(X_test)
rmse_lasso_test = np.sqrt(np.mean((pred_test_lasso - Y_test)**2))
print('rmse_lasso_test:',rmse_lasso_test)
print('r-squared_Rfreg_test',LassoReg.score(X_test,Y_test))
rsq_lasso_test = LassoReg.score(X_test,Y_test)
test_rmses["LassoRegression"] = rmse_lasso_test
RSquare_test["LassoRegression"] = rsq_lasso_test
# Out:
# rmse_lasso_test: 11357.502081338152
# r-squared_Rfreg_test 0.39106775467401506

# %%
crossvalidation = KFold(n_splits=10, random_state=None, shuffle=False)
rmse_sum = 0
for i in range(1,11):
    model_lassoReg = LassoReg.fit(X,Y)
    scores = cross_val_score(model_lassoReg, X, Y, scoring= 'neg_mean_squared_error', cv=crossvalidation,
    n_jobs=1)
    #print(scores)
    rmse = np.sqrt(abs(scores))
    rmse_sum = rmse_sum + np.mean(rmse)
    print("Lasso Regression-"+str(i) +" MSE:" + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)) + ", RMSE: " +str(np.mean(rmse)))
rmse_mean_lasso = rmse_sum/10
print(rmse_mean_lasso)
Kfold["LassoRegression"] = rmse_mean_lasso
# Out:
# Lasso Regression-1 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-2 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-3 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-4 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-5 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-6 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-7 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-8 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-9 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# Lasso Regression-10 MSE:194933968.41059196, STD: 189308260.9970274, RMSE: 12424.701576607877
# 12424.701576607878

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(LassoReg, GDP_Combine_X, GDP_Combine_Y, cv=4))
# Out:
# [-140.6419608     0.37606752    0.2715594     0.26425577]

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(pred_train_lasso, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_train, hist = True, bins = 5 , color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(pred_test_lasso, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_test, hist = True, bins = 5 , color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %% [markdown]
# ### Model 7 : Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet
ElasticNetReg = ElasticNet(alpha = 0.001)
ElasticNetReg.fit(X_train,Y_train)
# Out:
# ElasticNet(alpha=0.001, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
pred_train_ElasticNet = ElasticNetReg.predict(X_train)
rmse_en_train = np.sqrt(np.mean((pred_train_ElasticNet - Y_train)**2))
rmse_en_train = np.sqrt(np.mean((pred_train_ElasticNet - Y_train)**2))
print('rmse_elastic_train:',rmse_en_train)
print('r-squared_elasticnet_train',ElasticNetReg.score(X_train,Y_train))
rsq_en_train = ElasticNetReg.score(X_train,Y_train)
train_rmses["ElasticNetRegression"] = rmse_en_train
RSquare_train["ElasticNetRegression"] = rsq_en_train
# Out:
# rmse_elastic_train: 11098.558146004818
# r-squared_elasticnet_train 0.3773503106359769

# %%
pred_test_ElasticNet = ElasticNetReg.predict(X_test)
rmse_en_test = np.sqrt(np.mean((pred_test_ElasticNet - Y_test)**2))
rmse_en_test
print('rmse_elastic_test:',rmse_en_test)
print('r-squared_elasticnet_test',ElasticNetReg.score(X_test,Y_test))
rsq_en_test = ElasticNetReg.score(X_test,Y_test)
test_rmses["ElasticNetRegression"] = rmse_en_test
RSquare_test["ElasticNetRegression"] = rsq_en_test
# Out:
# rmse_elastic_test: 11357.503028157593
# r-squared_elasticnet_test 0.3910676531466001

# %%
crossvalidation = KFold(n_splits=10, random_state=None, shuffle=False)
rmse_sum = 0
for i in range(1,11):
    model_Elasticnet = ElasticNetReg.fit(X,Y)
    scores = cross_val_score(model_Elasticnet, X, Y, scoring= 'neg_mean_squared_error', cv=crossvalidation,
    n_jobs=1)
    #print(scores)
    rmse = np.sqrt(abs(scores))
    rmse_sum = rmse_sum + np.mean(rmse)
    print("ElasticNet Regression-"+str(i) +" MSE:" + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)) + ", RMSE: " +str(np.mean(rmse)))
rmse_mean_en = rmse_sum/10
print(rmse_mean_en)
Kfold["ElasticNetRegression"] = rmse_mean_en
# Out:
# ElasticNet Regression-1 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-2 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-3 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-4 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-5 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-6 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-7 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-8 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-9 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# ElasticNet Regression-10 MSE:194933968.40582803, STD: 189308260.99618274, RMSE: 12424.70157640104
# 12424.701576401041

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(pred_train_ElasticNet, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_train, hist = True, bins = 5 , color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot
import matplotlib.pyplot as plt

ax = sns.distplot(pred_test_ElasticNet, hist = True, bins = 5,color = 'red')
ax = sns.distplot(Y_test, hist = True, bins = 5 , color = 'blue')
ax.legend(labels=['Prediction','Actual'])
plt.show()

# %% [markdown]
# ### Using PCA

# %%
from sklearn.decomposition import PCA# Make an instance of the Model
pca = PCA(.95)
pca.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.95, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
model_pca = LinearRegression()
model_pca.fit(X_train_pca,Y_train)
y_pred_train_lr_pca = model_pca.predict(X_train_pca)
y_actual_train = Y_train
rmse_pca_lr_train = np.sqrt(mean_squared_error(y_actual_train, y_pred_train_lr_pca))
print('rmse_pca_lr_train:',rmse_pca_lr_train)
print('r-squared_PCAlr_train',model_pca.score(X_train_pca,Y_train))
# Out:
# rmse_pca_lr_train: 13626.085320993889
# r-squared_PCAlr_train 0.06145984079622613

# %%
y_pred_test_lr_pca = model_pca.predict(X_test_pca)
y_actual_test = Y_test
rmse_pca_lr_test = np.sqrt(mean_squared_error(y_actual_test, y_pred_test_lr_pca))
rmse_pca_lr_test
print('rmse_pca_lr_test:',rmse_pca_lr_test)
print('r-squared_PCAlr_test',model_pca.score(X_test_pca,Y_test))
# Out:
# rmse_pca_lr_test: 14096.050525400087
# r-squared_PCAlr_test 0.06200998007216463

# %%
from sklearn.tree import DecisionTreeRegressor

dtReg = DecisionTreeRegressor(max_depth=9)
dtReg.fit(X_train_pca,Y_train)

dtReg_y_pred_train_pca = dtReg.predict(X_train_pca)
rmse_pca_dtreg_train = np.sqrt(mean_squared_error(Y_train,dtReg_y_pred_train_pca))
print('rmse_pca_dtreg_train:',rmse_pca_dtreg_train)
print('r-squared_dtreg_train',dtReg.score(X_train_pca,Y_train))
# Out:
# rmse_pca_dtreg_train: 7188.131173877685
# r-squared_dtreg_train 0.7388183627201453

# %%
dtReg_y_pred_test_pca = dtReg.predict(X_test_pca)
rmse_pca_dtreg_test = np.sqrt(mean_squared_error(Y_test,dtReg_y_pred_test_pca))
print('rmse_pca_dtred_test:',rmse_pca_dtreg_test)
print('r-squared_PCAdtreg_test',dtReg.score(X_test_pca,Y_test))
# Out:
# rmse_pca_dtred_test: 8727.75182450635
# r-squared_PCAdtreg_test 0.6404095915095226

# %%
Rfreg_pca = RandomForestRegressor(max_features=2, n_estimators=30)
Rfreg_pca.fit(X_train_pca, Y_train)
Rfreg_y_pred_train_pca = Rfreg_pca.predict(X_train_pca)
rmse_pca_rfreg_train = np.sqrt(mean_squared_error(Y_train,Rfreg_y_pred_train_pca))
print('rmse_pca_rfreg_train:',rmse_pca_rfreg_train)
print('r-squared_rfreg_train',Rfreg_pca.score(X_train_pca,Y_train))
# Out:
# rmse_pca_rfreg_train: 3727.4416130565996
# r-squared_rfreg_train 0.9297684341869695

# %%
Rfreg_y_pred_test_pca = Rfreg_pca.predict(X_test_pca)
rmse_pca_rfreg_test = np.sqrt(mean_squared_error(Y_test,Rfreg_y_pred_test))
print('rmse_pca_rfreg_test:',rmse_pca_rfreg_test)
print('r-squared_rfreg_test',Rfreg_pca.score(X_test_pca,Y_test))
# Out:
# rmse_pca_rfreg_test: 5693.480164833861
# r-squared_rfreg_test 0.6635202611952076

# %% [markdown]
# ## Adding New Features

# %%
GDP_Combine_new=GDP_Combine
GDP_Combine_new['Literacy_creditToPriva']=GDP_Combine['LiteracyRate_Adult']*GDP_Combine['CreditTo_PrivateSector'];
GDP_Combine_new['Literacy_RuralPop']=GDP_Combine['LiteracyRate_Adult']*GDP_Combine['RuralPopulation_PerCent'];
GDP_Combine_new['Literacy_AgriMach']=GDP_Combine['LiteracyRate_Adult']*GDP_Combine['Agricultural_Machines'];
GDP_Combine_new['Literacy_AccountRa']=GDP_Combine['LiteracyRate_Adult']*GDP_Combine['AccountsRatio_FinancialInst'];
GDP_Combine_new['Literacy_ATM']=GDP_Combine['LiteracyRate_Adult']*GDP_Combine['ATMMachines_Ratio'];
GDP_Combine_new['Literacy_BirthAT']=GDP_Combine['LiteracyRate_Adult']*GDP_Combine['BirthsAttendedby_SkilledStaff'];
GDP_Combine_new['Literacy_Legal']=GDP_Combine['LiteracyRate_Adult']*GDP_Combine['LegalRights_Strength'];
GDP_Combine_new['Literacy_Woman']=GDP_Combine['LiteracyRate_Adult']*GDP_Combine['Women_Informed_Choices'];
GDP_Combine_new['Woman_Rural']=GDP_Combine['Women_Informed_Choices']*GDP_Combine['RuralPopulation_PerCent'];
GDP_Combine_new['Woman_CreditToPriv']=GDP_Combine['Women_Informed_Choices']*GDP_Combine['CreditTo_PrivateSector'];
GDP_Combine_new['Woman_AgriM']=GDP_Combine['Women_Informed_Choices']*GDP_Combine['Agricultural_Machines'];
GDP_Combine_new['Woman_ATM']=GDP_Combine['Women_Informed_Choices']*GDP_Combine['ATMMachines_Ratio'];
GDP_Combine_new['Woman_BirthAT']=GDP_Combine['Women_Informed_Choices']*GDP_Combine['BirthsAttendedby_SkilledStaff'];

# %%
plt.figure(figsize=(12,12))
sns.heatmap(GDP_Combine_new.corr(),annot=True,fmt='.2f',cmap='coolwarm')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
### BEGIN SOLUTION

GDP_Combine_new_X = GDP_Combine_new.drop(['value'],axis=1)
GDP_Combine_new_X.rename(columns={'variable':'Year'}, inplace=True)
GDP_Combine_new_X = GDP_Combine_new_X[['Year','Women_Informed_Choices','RuralPopulation_PerCent','LegalRights_Strength',
                                       'CreditTo_PrivateSector','BirthsAttendedby_SkilledStaff','ATMMachines_Ratio',
                                       'Agricultural_Machines','LiteracyRate_Adult','AccountsRatio_FinancialInst',
                                      'Literacy_creditToPriva','Literacy_RuralPop','Literacy_AgriMach',
                                       'Literacy_AccountRa','Literacy_ATM','Literacy_BirthAT','Literacy_Legal',
                                       'Literacy_Woman','Woman_Rural','Woman_CreditToPriv','Woman_AgriM','Woman_ATM',
                                       'Woman_BirthAT']]

GDP_Combine_new_Y = GDP_Combine_new['value']
print(GDP_Combine_new_X.shape,GDP_Combine_new_Y.shape)

X_train_new,X_test_new,Y_train_new,Y_test_new = train_test_split(GDP_Combine_new_X,GDP_Combine_new_Y,test_size=0.2,random_state=40)
# Out:
# (11504, 23) (11504,)

# %%
#Random Forest tree method
from sklearn import ensemble
from sklearn.ensemble import RandomForestRegressor
from pandas import Series, DataFrame
from sklearn.model_selection import cross_val_score

Rfreg_new = RandomForestRegressor(max_features=23, n_estimators=30)
Rfreg_new .fit(X_train_new , Y_train_new )
Rfreg_y_pred_train_new  = Rfreg_new .predict(X_train_new )
train_mse_Rfreg_new  = np.sqrt(mean_squared_error(Y_train_new ,Rfreg_y_pred_train_new))

#testing the model
Rfreg_y_pred_test_new  = Rfreg_new.predict(X_test_new )
test_mse_Rfreg_new  = np.sqrt(mean_squared_error(Y_test_new ,Rfreg_y_pred_test_new))
 
#cross validation

Rfreg_kf_new  = RandomForestRegressor(max_features=10, n_estimators=30)

print("New RMSE_train_Random= ",train_mse_Rfreg_new,
     "\nNew RMSE_test_Random= ",test_mse_Rfreg_new,
     "\nNew train_Rfeg score= ",Rfreg_new .score(X_train_new ,Y_train_new ),
     "\nNew test_Rfeg score= ",Rfreg_new .score(X_test_new ,Y_test_new ),
     "\nNew Cross validation score",cross_val_score(Rfreg_kf_new , GDP_Combine_new_X , GDP_Combine_new_Y,cv=4))
# Out:
# New RMSE_train_Random=  2897.7148196368207
# New RMSE_test_Random=  5591.614707349337
# New train_Rfeg score=  0.9575554497405006
# New test_Rfeg score=  0.8524029086280321
# New Cross validation score [-3.98316735  0.51997681  0.69670676  0.54460092]

# %%
# Reduced Model 1
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
model = LinearRegression()
Y = GDP_Combine['value']
#X =  GDP_Combine['BirthsAttendedby_SkilledStaff'] + GDP_Combine['Women_Informed_Choices'] + GDP_Combine['RuralPopulation_PerCent'] + GDP_Combine['CreditTo_PrivateSector'] + GDP_Combine['ATMMachines_Ratio']+ GDP_combine['LiteracyRate_Adult']
X = GDP_Combine['RuralPopulation_PerCent'] + GDP_Combine['BirthsAttendedby_SkilledStaff'] + GDP_Combine['ATMMachines_Ratio'] 
print(Y.size)
print(X.size)

RuralPopulation_PerCent = GDP_Combine['RuralPopulation_PerCent'] 

BirthsAttendedby_SkilledStaff = GDP_Combine['BirthsAttendedby_SkilledStaff']
ATMMachines_Ratio = GDP_Combine['ATMMachines_Ratio']

#model_hyp = ols("GDP_Combine_Y ~ GDP_Combine_X", X_train).fit()
model_hyp_reduced1 = ols('Y ~RuralPopulation_PerCent + BirthsAttendedby_SkilledStaff + ATMMachines_Ratio', GDP_Combine).fit()
print(model_hyp_reduced1.summary())
# Out:
# 11504
# 11504
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     1687.
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        00:18:36   Log-Likelihood:            -1.2419e+05
# No. Observations:               11504   AIC:                         2.484e+05
# Df Residuals:                   11500   BIC:                         2.484e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                      7976.5484   1123.485      7.100      0.000    5774.326    1.02e+04
# RuralPopulation_PerCent        -227.6990      4.716    -48.279      0.000    -236.944    -218.454
# BirthsAttendedby_SkilledStaff    28.6684     11.868      2.416      0.016       5.404      51.932
# ATMMachines_Ratio               201.3025      5.506     36.561      0.000     190.510     212.095
# ==============================================================================
# Omnibus:                    12156.213   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1166757.570
# Skew:                           5.226   Prob(JB):                         0.00
# Kurtosis:                      51.217   Cond. No.                     1.12e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
model = LinearRegression()
Y = GDP_Combine['value']
#X =  GDP_Combine['BirthsAttendedby_SkilledStaff'] + GDP_Combine['Women_Informed_Choices'] + GDP_Combine['RuralPopulation_PerCent'] + GDP_Combine['CreditTo_PrivateSector'] + GDP_Combine['ATMMachines_Ratio']+ GDP_combine['LiteracyRate_Adult']
X = GDP_Combine['Women_Informed_Choices'] + GDP_Combine['RuralPopulation_PerCent'] + GDP_Combine['CreditTo_PrivateSector'] + GDP_Combine['BirthsAttendedby_SkilledStaff'] + GDP_Combine['ATMMachines_Ratio'] + GDP_Combine['LiteracyRate_Adult']
print(Y.size)
print(X.size)
Women_Informed_Choices = GDP_Combine['Women_Informed_Choices']
RuralPopulation_PerCent = GDP_Combine['RuralPopulation_PerCent'] 
CreditTo_PrivateSector = GDP_Combine['CreditTo_PrivateSector']
BirthsAttendedby_SkilledStaff = GDP_Combine['BirthsAttendedby_SkilledStaff']
ATMMachines_Ratio = GDP_Combine['ATMMachines_Ratio']
LiteracyRate_Adult = GDP_Combine['LiteracyRate_Adult']
#model_hyp = ols("GDP_Combine_Y ~ GDP_Combine_X", X_train).fit()
model_hyp_reduced2 = ols('Y ~ Women_Informed_Choices + RuralPopulation_PerCent + CreditTo_PrivateSector + BirthsAttendedby_SkilledStaff + ATMMachines_Ratio + LiteracyRate_Adult', GDP_Combine).fit()
print(model_hyp_reduced2.summary())
# Out:
# 11504
# 11504
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     846.5
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        00:18:39   Log-Likelihood:            -1.2418e+05
# No. Observations:               11504   AIC:                         2.484e+05
# Df Residuals:                   11497   BIC:                         2.484e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                      1.126e+04   4072.352      2.765      0.006    3277.843    1.92e+04
# Women_Informed_Choices          -91.5529     84.965     -1.078      0.281    -258.098      74.993
# RuralPopulation_PerCent        -227.1301      4.727    -48.052      0.000    -236.395    -217.865
# CreditTo_PrivateSector            1.6826      0.580      2.901      0.004       0.546       2.820
# BirthsAttendedby_SkilledStaff    26.9931     11.950      2.259      0.024       3.568      50.418
# ATMMachines_Ratio               200.2210      5.513     36.316      0.000     189.414     211.028
# LiteracyRate_Adult                3.9912      2.021      1.975      0.048       0.030       7.953
# ==============================================================================
# Omnibus:                    12152.596   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1167950.797
# Skew:                           5.223   Prob(JB):                         0.00
# Kurtosis:                      51.244   Cond. No.                     1.13e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
model = LinearRegression()
Y = GDP_Combine['value']
#X =  GDP_Combine['BirthsAttendedby_SkilledStaff'] + GDP_Combine['Women_Informed_Choices'] + GDP_Combine['RuralPopulation_PerCent'] + GDP_Combine['CreditTo_PrivateSector'] + GDP_Combine['ATMMachines_Ratio']+ GDP_combine['LiteracyRate_Adult']
X = GDP_Combine['Women_Informed_Choices'] + GDP_Combine['RuralPopulation_PerCent'] + GDP_Combine['CreditTo_PrivateSector'] + GDP_Combine['BirthsAttendedby_SkilledStaff'] + GDP_Combine['ATMMachines_Ratio'] + GDP_Combine['LiteracyRate_Adult']
print(Y.size)
print(X.size)
Women_Informed_Choices = GDP_Combine['Women_Informed_Choices']
RuralPopulation_PerCent = GDP_Combine['RuralPopulation_PerCent'] 
CreditTo_PrivateSector = GDP_Combine['CreditTo_PrivateSector']
BirthsAttendedby_SkilledStaff = GDP_Combine['BirthsAttendedby_SkilledStaff']
ATMMachines_Ratio = GDP_Combine['ATMMachines_Ratio']
LiteracyRate_Adult = GDP_Combine['LiteracyRate_Adult']
LegalRights_Strength = GDP_Combine['LegalRights_Strength']
Agricultural_Machines = GDP_Combine['Agricultural_Machines']
AccountsRatio_FinancialInst = GDP_Combine['AccountsRatio_FinancialInst']

#model_hyp = ols("GDP_Combine_Y ~ GDP_Combine_X", X_train).fit()
model_hyp_full = ols('Y ~ Women_Informed_Choices + RuralPopulation_PerCent + CreditTo_PrivateSector + BirthsAttendedby_SkilledStaff + ATMMachines_Ratio + LiteracyRate_Adult + LegalRights_Strength + Agricultural_Machines + AccountsRatio_FinancialInst', GDP_Combine).fit()
print(model_hyp_full.summary())
type(X)
# Out:
# 11504
# 11504
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.326
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     616.6
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        00:18:42   Log-Likelihood:            -1.2402e+05
# No. Observations:               11504   AIC:                         2.481e+05
# Df Residuals:                   11494   BIC:                         2.481e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                       418.6902   4182.471      0.100      0.920   -7779.666    8617.046
# Women_Informed_Choices         -101.3110     83.820     -1.209      0.227    -265.612      62.990
# RuralPopulation_PerCent        -205.0996      4.842    -42.357      0.000    -214.591    -195.608
# CreditTo_PrivateSector            1.4490      0.572      2.532      0.011       0.327       2.571
# BirthsAttendedby_SkilledStaff    19.4976     11.793      1.653      0.098      -3.619      42.615
# ATMMachines_Ratio               194.3651      5.587     34.792      0.000     183.415     205.316
# LiteracyRate_Adult                2.4690      1.996      1.237      0.216      -1.443       6.381
# LegalRights_Strength            242.8778    143.486      1.693      0.091     -38.380     524.135
# Agricultural_Machines             4.6075      0.281     16.400      0.000       4.057       5.158
# AccountsRatio_FinancialInst     170.7052     22.092      7.727      0.000     127.401     214.010
# ==============================================================================
# Omnibus:                    12430.504   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1302623.841
# Skew:                           5.402   Prob(JB):                         0.00
# Kurtosis:                      53.998   Cond. No.                     2.06e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.06e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# pandas.core.series.Series

# %%
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
model = LinearRegression()
Y = GDP_Combine_new['value']
#X =  GDP_Combine['BirthsAttendedby_SkilledStaff'] + GDP_Combine['Women_Informed_Choices'] + GDP_Combine['RuralPopulation_PerCent'] + GDP_Combine['CreditTo_PrivateSector'] + GDP_Combine['ATMMachines_Ratio']+ GDP_combine['LiteracyRate_Adult']
X = GDP_Combine_new['Women_Informed_Choices'] + GDP_Combine_new['RuralPopulation_PerCent'] + GDP_Combine_new['CreditTo_PrivateSector'] + GDP_Combine_new['BirthsAttendedby_SkilledStaff'] + GDP_Combine_new['ATMMachines_Ratio'] + GDP_Combine_new['LiteracyRate_Adult'] + GDP_Combine_new['Literacy_creditToPriva'] + GDP_Combine_new['Literacy_RuralPop'] + GDP_Combine_new['Literacy_AgriMach'] + GDP_Combine_new['Literacy_AccountRa'] + GDP_Combine_new['Literacy_ATM'] + GDP_Combine_new['Literacy_BirthAT']+ GDP_Combine_new['Literacy_Legal'] + GDP_Combine_new['Literacy_Woman'] + GDP_Combine_new['Woman_Rural'] + GDP_Combine_new['Woman_CreditToPriv']+ GDP_Combine_new['Woman_AgriM'] + GDP_Combine_new['Woman_ATM'] + GDP_Combine_new['Woman_BirthAT']
print(Y.size)
print(X.size)

Women_Informed_Choices = GDP_Combine_new['Women_Informed_Choices']
RuralPopulation_PerCent = GDP_Combine_new['RuralPopulation_PerCent'] 
CreditTo_PrivateSector = GDP_Combine_new['CreditTo_PrivateSector']
BirthsAttendedby_SkilledStaff = GDP_Combine_new['BirthsAttendedby_SkilledStaff']
ATMMachines_Ratio = GDP_Combine_new['ATMMachines_Ratio']
LiteracyRate_Adult = GDP_Combine_new['LiteracyRate_Adult']
LegalRights_Strength = GDP_Combine_new['LegalRights_Strength']
Agricultural_Machines = GDP_Combine_new['Agricultural_Machines']
AccountsRatio_FinancialInst = GDP_Combine_new['AccountsRatio_FinancialInst']
Literacy_creditToPriva = GDP_Combine_new['Literacy_creditToPriva']
Literacy_RuralPop = GDP_Combine_new['Literacy_RuralPop']
Literacy_AgriMach = GDP_Combine_new['Literacy_AgriMach']
Literacy_AccountRa = GDP_Combine_new['Literacy_AccountRa']
Literacy_ATM = GDP_Combine_new['Literacy_ATM']
Literacy_BirthAT = GDP_Combine_new['Literacy_BirthAT']
Literacy_Legal = GDP_Combine_new['Literacy_Legal']
Literacy_Woman = GDP_Combine_new['Literacy_Woman']
Woman_Rural = GDP_Combine_new['Woman_Rural']
Woman_CreditToPriv = GDP_Combine_new['Woman_CreditToPriv']
Woman_AgriM = GDP_Combine_new['Woman_AgriM']
Woman_ATM = GDP_Combine_new['Woman_ATM']
Woman_BirthAT = GDP_Combine_new['Woman_BirthAT']



model_hyp_full_new = ols('Y ~ Women_Informed_Choices + RuralPopulation_PerCent + CreditTo_PrivateSector + BirthsAttendedby_SkilledStaff + ATMMachines_Ratio + LiteracyRate_Adult + LegalRights_Strength + Agricultural_Machines + AccountsRatio_FinancialInst + Literacy_creditToPriva + Literacy_RuralPop + Literacy_AgriMach + Literacy_AccountRa + Literacy_ATM + Literacy_BirthAT + Literacy_Legal + Literacy_Woman + Woman_Rural + Woman_CreditToPriv + Woman_AgriM + Woman_ATM + Woman_BirthAT', GDP_Combine_new).fit()
print(model_hyp_full_new.summary())
type(X)
# Out:
# 11504
# 11504
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     255.1
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        00:18:46   Log-Likelihood:            -1.2400e+05
# No. Observations:               11504   AIC:                         2.480e+05
# Df Residuals:                   11481   BIC:                         2.482e+05
# Df Model:                          22
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                       6.58e+04   4.34e+04      1.517      0.129   -1.92e+04    1.51e+05
# Women_Informed_Choices        -1051.2009    921.834     -1.140      0.254   -2858.152     755.750
# RuralPopulation_PerCent        -647.7777    299.859     -2.160      0.031   -1235.553     -60.003
# CreditTo_PrivateSector         -121.8794    301.768     -0.404      0.686    -713.396     469.637
# BirthsAttendedby_SkilledStaff  -185.4542    224.482     -0.826      0.409    -625.478     254.569
# ATMMachines_Ratio               118.7327    421.212      0.282      0.778    -706.916     944.381
# LiteracyRate_Adult              -76.4296     43.036     -1.776      0.076    -160.787       7.928
# LegalRights_Strength           -507.5149    534.420     -0.950      0.342   -1555.069     540.039
# Agricultural_Machines           -22.0005    118.292     -0.186      0.852    -253.873     209.872
# AccountsRatio_FinancialInst      11.9640     71.136      0.168      0.866    -127.475     151.403
# Literacy_creditToPriva           -0.1238      0.067     -1.853      0.064      -0.255       0.007
# Literacy_RuralPop                 0.1550      0.102      1.520      0.129      -0.045       0.355
# Literacy_AgriMach                 0.0019      0.014      0.141      0.888      -0.025       0.029
# Literacy_AccountRa                0.6766      0.274      2.471      0.013       0.140       1.213
# Literacy_ATM                      0.4807      0.099      4.881      0.000       0.288       0.674
# Literacy_BirthAT                  0.1649      0.139      1.183      0.237      -0.108       0.438
# Literacy_Legal                    2.8074      2.012      1.395      0.163      -1.136       6.751
# Literacy_Woman                   -0.1121      0.809     -0.139      0.890      -1.697       1.473
# Woman_Rural                       8.5682      6.369      1.345      0.179      -3.916      21.053
# Woman_CreditToPriv                3.3966      6.428      0.528      0.597      -9.204      15.997
# Woman_AgriM                       0.5574      2.528      0.220      0.826      -4.399       5.513
# Woman_ATM                        -1.1600      8.996     -0.129      0.897     -18.794      16.474
# Woman_BirthAT                     3.5162      4.782      0.735      0.462      -5.857      12.890
# ==============================================================================
# Omnibus:                    12457.156   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1319979.219
# Skew:                           5.418   Prob(JB):                         0.00
# Kurtosis:                      54.345   Cond. No.                     5.76e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.76e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# pandas.core.series.Series

# %%
perf = pd.DataFrame({"Model": Models})
perf["Train.RMSE"] = train_rmses.values()
perf["Test.RMSE"] = test_rmses.values()
perf['Kfold'] = Kfold.values()
perf['RSquare_train'] = RSquare_train.values()
perf['RSquare_test'] = RSquare_test.values()
perf
# Out:
#                         Model    Train.RMSE      Test.RMSE         Kfold  \
# 0  Multiple Linear Regression  11098.558146   11357.502081  13714.769075
# 1       Polynomial Regression   9165.460690  161698.415494  15711.289141
# 2    Decision Tree Regression   2255.186797    6300.789568  15368.486568
# 3    Random Forest Regression   2902.347557    5441.296505  11610.635767
# 4            Ridge Regression  11098.558146   11357.502088  12424.701550
# 5            Lasso Regression  11098.558146   11357.502081  12424.701577
# 6      Elastic Net Regression  11098.558146   11357.503028  12424.701576
#
#    RSquare_train  RSquare_test
# 0       0.377350      0.391068
# 1       0.575362      0.550000
# 2       0.974292      0.812590
# 3       0.957420      0.860232
# 4       0.377350      0.391068
# 5       0.377350      0.391068
# 6       0.377350      0.391068

# %%
GDP_Combine.head(5)
# Out:
#    Country Name Country Code variable        value  Women_Informed_Choices  \
# 1   Afghanistan          AFG     1960    59.777327               46.753333
# 11    Australia          AUS     1960  1809.311452               46.753333
# 12      Austria          AUT     1960   935.460427               46.753333
# 14      Burundi          BDI     1960    70.349079               46.753333
# 15      Belgium          BEL     1960  1273.691659               46.753333
#
#     RuralPopulation_PerCent  LegalRights_Strength  CreditTo_PrivateSector  \
# 1                    91.779               5.01029                9.272727
# 11                   18.471               5.01029               19.129021
# 12                   35.280               5.01029               44.704804
# 14                   97.923               5.01029               44.704804
# 15                    7.540               5.01029               44.704804
#
#     BirthsAttendedby_SkilledStaff  ATMMachines_Ratio  Agricultural_Machines  \
# 1                       87.418299          40.080656              286.92997
# 11                      87.418299          40.080656              286.92997
# 12                      87.418299          40.080656              286.92997
# 14                      87.418299          40.080656              286.92997
# 15                      87.418299          40.080656              286.92997
#
#     LiteracyRate_Adult  AccountsRatio_FinancialInst
# 1            286.92997                    52.493345
# 11           286.92997                    52.493345
# 12           286.92997                    52.493345
# 14           286.92997                    52.493345
# 15           286.92997                    52.493345

# %%
#Country = Belgium
X_sample = GDP_Combine_X
X_sample['Year'] = 1960
X_sample['Women_Informed_Choices'] = 46.753333
X_sample['RuralPopulation_PerCent'] = 7.540
X_sample['LegalRights_Strength'] = 5.01029
X_sample['CreditTo_PrivateSector'] = 44.704804
X_sample['BirthsAttendedby_SkilledStaff'] = 87.418299
X_sample['ATMMachines_Ratio'] = 40.080656
X_sample['Agricultural_Machines'] = 286.92997
X_sample['LiteracyRate_Adult'] = 286.92997
X_sample['AccountsRatio_FinancialInst'] = 52.493345

# %%
Rfreg_y_pred_sample = Rfreg.predict(X_sample)
print('The predicted GDP valus is:',Rfreg_y_pred_sample.max())
# Out:
# The predicted GDP valus is: 1334.3170685208838

# %%
'''Australia
AUS
1960
1809.311452
'''
X_sample1 = GDP_Combine_X
X_sample1['Year'] = 1960
X_sample1['Women_Informed_Choices'] = 46.753333
X_sample1['RuralPopulation_PerCent'] = 18.471
X_sample1['LegalRights_Strength'] = 5.01029
X_sample1['CreditTo_PrivateSector'] = 19.129021
X_sample1['BirthsAttendedby_SkilledStaff'] = 87.418299
X_sample1['ATMMachines_Ratio'] = 40.080656
X_sample1['Agricultural_Machines'] = 286.92997
X_sample1['LiteracyRate_Adult'] = 286.92997
X_sample1['AccountsRatio_FinancialInst'] = 52.493345

# %%
Rfreg_y_pred_sample1 = Rfreg.predict(X_sample1)
Rfreg_y_pred_sample1.max()
# Out:
# 1520.4910149040866

# %%
X_sample2 = GDP_Combine_X
X_sample2['Year'] = 1960
X_sample2['Women_Informed_Choices'] = 46.753333
X_sample2['RuralPopulation_PerCent'] = 30.939
X_sample2['LegalRights_Strength'] = 5.01029
X_sample2['CreditTo_PrivateSector'] = 18.260185
X_sample2['BirthsAttendedby_SkilledStaff'] = 87.418299
X_sample2['ATMMachines_Ratio'] = 40.080656
X_sample2['Agricultural_Machines'] = 286.92997
X_sample2['LiteracyRate_Adult'] = 286.92997
X_sample2['AccountsRatio_FinancialInst'] = 52.493345

# %%
Rfreg_y_pred_sample2 = Rfreg.predict(X_sample2)
Rfreg_y_pred_sample2.max()
# Out:
# 2292.918433763732

# %%
GDP_Combine.tail(20)
# Out:
#                          Country Name Country Code variable         value  \
# 15025                         Tunisia          TUN     2016   3688.646375
# 15026                          Turkey          TUR     2016  10862.600399
# 15027                          Tuvalu          TUV     2016   3083.615251
# 15028                        Tanzania          TZA     2016    851.866046
# 15029                          Uganda          UGA     2016    580.383539
# 15030                         Ukraine          UKR     2016   2072.463395
# 15031             Upper middle income          UMC     2016   7994.022621
# 15032                         Uruguay          URY     2016  15220.566025
# 15033                   United States          USA     2016  57638.159088
# 15034                      Uzbekistan          UZB     2016   2110.647872
# 15035  St. Vincent and the Grenadines          VCT     2016   7006.596196
# 15039                         Vietnam          VNM     2016   2214.387662
# 15040                         Vanuatu          VUT     2016   2860.566475
# 15041                           World          WLD     2016  10191.309818
# 15042                           Samoa          WSM     2016   4030.013144
# 15043                          Kosovo          XKX     2016   3661.429847
# 15044                     Yemen, Rep.          YEM     2016    990.334774
# 15045                    South Africa          ZAF     2016   5284.603604
# 15046                          Zambia          ZMB     2016   1269.573537
# 15047                        Zimbabwe          ZWE     2016   1029.076649
#
#        Women_Informed_Choices  RuralPopulation_PerCent  LegalRights_Strength  \
# 15025               46.753333                32.953000              3.000000
# 15026               46.753333                26.113000              2.000000
# 15027               46.753333                39.380000              5.010290
# 15028               46.753333                67.684000              5.000000
# 15029               46.753333                83.556000              6.000000
# 15030               46.753333                30.085000              8.000000
# 15031               46.753333                34.954541              5.137255
# 15032               46.753333                 4.540000              4.000000
# 15033               46.753333                18.212000             11.000000
# 15034               46.753333                63.521000              6.000000
# 15035               46.753333                49.101000              5.000000
# 15039               46.753333                65.764000              7.000000
# 15040               46.753333                73.559000             11.000000
# 15041               46.753333                45.701908              5.136842
# 15042               46.753333                81.045000              5.000000
# 15043               46.753333                50.444357              9.000000
# 15044               46.753333                64.813000              0.000000
# 15045               46.753333                34.705000              5.000000
# 15046               46.753333                58.621000              7.000000
# 15047               46.753333                67.723000              5.000000
#
#        CreditTo_PrivateSector  BirthsAttendedby_SkilledStaff  \
# 15025               81.155319                      87.418299
# 15026               69.852675                      87.418299
# 15027               44.704804                      87.418299
# 15028               14.278778                      63.700000
# 15029               14.545330                      87.418299
# 15030               47.334073                      87.418299
# 15031              118.992695                      87.418299
# 15032               28.161111                      87.418299
# 15033              192.165500                      87.418299
# 15034               44.704804                      87.418299
# 15035               50.941965                      87.418299
# 15039              123.814875                      87.418299
# 15040               68.515227                      87.418299
# 15041              131.567969                      87.418299
# 15042               80.041922                      87.418299
# 15043               39.269275                      87.418299
# 15044               44.704804                      87.418299
# 15045              144.414242                      87.418299
# 15046               12.039253                      87.418299
# 15047               44.704804                      87.418299
#
#        ATMMachines_Ratio  Agricultural_Machines  LiteracyRate_Adult  \
# 15025          27.440945              286.92997           286.92997
# 15026          78.076702              286.92997           286.92997
# 15027          40.080656              286.92997           286.92997
# 15028          40.080656              286.92997           286.92997
# 15029           4.365255              286.92997           286.92997
# 15030          88.553238              286.92997           286.92997
# 15031          57.606234              286.92997            96.52922
# 15032          81.980145              286.92997           286.92997
# 15033          40.080656              286.92997           286.92997
# 15034          21.597743              286.92997           286.92997
# 15035          34.854094              286.92997           286.92997
# 15039          24.501957              286.92997           286.92997
# 15040          40.080656              286.92997           286.92997
# 15041          47.552545              286.92997            89.83772
# 15042          47.076776              286.92997           286.92997
# 15043          38.326881              286.92997           286.92997
# 15044          40.080656              286.92997           286.92997
# 15045          69.289789              286.92997           286.92997
# 15046          11.152524              286.92997           286.92997
# 15047           6.010074              286.92997           286.92997
#
#        AccountsRatio_FinancialInst
# 15025                    52.493345
# 15026                    52.493345
# 15027                    52.493345
# 15028                    52.493345
# 15029                    52.493345
# 15030                    52.493345
# 15031                    52.493345
# 15032                    52.493345
# 15033                    52.493345
# 15034                    52.493345
# 15035                    52.493345
# 15039                    52.493345
# 15040                    52.493345
# 15041                    52.493345
# 15042                    52.493345
# 15043                    52.493345
# 15044                    52.493345
# 15045                    52.493345
# 15046                    52.493345
# 15047                    52.493345

# %%
#Country = United States
X_sample2 = GDP_Combine_X
X_sample2['Year'] = 2016
X_sample2['Women_Informed_Choices'] = 46.753333
X_sample2['RuralPopulation_PerCent'] = 18.212000
X_sample2['LegalRights_Strength'] = 11.000000
X_sample2['CreditTo_PrivateSector'] = 192.165500
X_sample2['BirthsAttendedby_SkilledStaff'] = 87.418299
X_sample2['ATMMachines_Ratio'] = 40.080656
X_sample2['Agricultural_Machines'] = 286.92997
X_sample2['LiteracyRate_Adult'] = 286.92997
X_sample2['AccountsRatio_FinancialInst'] = 52.493345

# %%
Rfreg_y_pred_sample2 = Rfreg.predict(X_sample2)
print('The predcited GDP value is :',Rfreg_y_pred_sample2.max())
# Out:
# The predcited GDP value is : 57414.72022395733
